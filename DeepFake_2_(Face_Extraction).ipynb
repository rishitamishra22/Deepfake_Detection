# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva-Peshkar/DeepFake-Detector/blob/main/DeepFake_2_(Face_Extraction).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 4.2MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras>=2.0.0->mtcnn) (1.15.0)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Colab Notebooks/DeepFake/
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Colab Notebooks/DeepFake

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from tqdm.notebook import tqdm
import time
import os
from google.colab.patches import cv2_imshow

# %%
main_dir = '/gdrive/My Drive/Colab Notebooks/DeepFake/'

# %%
'''This is the function for extracting the faces from frames.
The detect_mtcnn function, is the primary function that uses MTCNN as a detector to detect, extract and append the face to a list faces which it returns.
The face_extractor function takes the directories where the frames are stored and the directory where the images are to be stored. 
It calls the detect_mtcnn function.

The directory structure should be as follows:

+ DeepFake                      |       +DeepFake
  + Real                        |         +Fake
    +RealFrames (img_dir)       |           +FakeFrames (img_dir)
                                |            
'''

from mtcnn import MTCNN
detector = MTCNN()

def detect_mtcnn(detector, images, size):      #detecting faces
    faces = []
    for image in tqdm(images):                      #tqdm for progressbar
      try:
          boxes = detector.detect_faces(image)        #get the dictionary of coordinates
          if(len(boxes[0])==3):
            box = boxes[0]['box']   
            face = image[box[1]:box[3]+box[1], box[0]:box[2]+box[0]]      #cropping the face
            faces.append(cv2.resize(face, size))                    #resizing the face and adding it to the list
      except:
        print("Skipping...")
        continue
    return faces

def face_extractor(img_dir,dest_dir):
  print("\n ******    Welcome to Face Extractor     ******        \n\n    Progress: ") 
  img = [cv2.imread(os.path.join(img_dir,file)) for file in os.listdir(img_dir) if file.endswith('.jpg')] #reading images that end with .jpg or .png
  extracted_faces = detect_mtcnn(detector,img,(299,299))  #calling detect_mtcnn function

  count = 0

  for ex_face in extracted_faces:
    count = count+1
    cv2.imwrite(os.path.join(dest_dir,f'frame{count}.jpg'),ex_face)  #writing image to destination folder
    print(f"Face from image {count} extracted and saved!")
  return extracted_faces

# %%
#Function to create new directories if they do not exist. Syntax: dir_creator(parent_dir_path , new_dir_name)

def dir_creator(path_val,dir_name):
  if(os.path.isdir(os.path.join(path_val,dir_name))):
    print(f"Folder named: {dir_name}, already exists, good to go!\n")
  else:
    print(f"Folder named: {dir_name}, created for you, go ahead!\n")
    os.mkdir(os.path.join(path_val,dir_name))

# %%
dir_creator(os.path.join(main_dir,'Real'),'Pristine')
dir_creator(os.path.join(main_dir,'Fake'),'Deepfake')
# Out:
# Folder named: Pristine, created for you, go ahead!
#
# Folder named: Deepfake, already exists, good to go!

# %%
base_real= os.path.join(main_dir,'Real')
base_fake = os.path.join(main_dir,'Fake')

face_extractor(os.path.join(base_real,'RealFrames'),os.path.join(base_real,'Pristine'))
# Out:
#  ******    Welcome to Face Extractor     ******
#
#     Progress:
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
# Skipping...
#
# Face from image 1 extracted and saved!
# Face from image 2 extracted and saved!
# Face from image 3 extracted and saved!
# Face from image 4 extracted and saved!
# Face from image 5 extracted and saved!
# Face from image 6 extracted and saved!
# Face from image 7 extracted and saved!
# Face from image 8 extracted and saved!
# Face from image 9 extracted and saved!
# Face from image 10 extracted and saved!
# Face from image 11 extracted and saved!
# Face from image 12 extracted and saved!
# Face from image 13 extracted and saved!
# Face from image 14 extracted and saved!
# Face from image 15 extracted and saved!
# Face from image 16 extracted and saved!
# Face from image 17 extracted and saved!
# Face from image 18 extracted and saved!
# Face from image 19 extracted and saved!
# Face from image 20 extracted and saved!
# Face from image 21 extracted and saved!
# Face from image 22 extracted and saved!
# Face from image 23 extracted and saved!
# Face from image 24 extracted and saved!
# Face from image 25 extracted and saved!
# Face from image 26 extracted and saved!
# Face from image 27 extracted and saved!
# Face from image 28 extracted and saved!
# Face from image 29 extracted and saved!
# Face from image 30 extracted and saved!
# Face from image 31 extracted and saved!
# Face from image 32 extracted and saved!
# Face from image 33 extracted and saved!
# Face from image 34 extracted and saved!
# Face from image 35 extracted and saved!
# Face from image 36 extracted and saved!
# Face from image 37 extracted and saved!
# Face from image 38 extracted and saved!
# Face from image 39 extracted and saved!
# Face from image 40 extracted and saved!
# Face from image 41 extracted and saved!
# Face from image 42 extracted and saved!
# Face from image 43 extracted and saved!
# Face from image 44 extracted and saved!
# Face from image 45 extracted and saved!
# Face from image 46 extracted and saved!
# Face from image 47 extracted and saved!
# Face from image 48 extracted and saved!
# Face from image 49 extracted and saved!
# Face from image 50 extracted and saved!
# Face from image 51 extracted and saved!
# Face from image 52 extracted and saved!
# Face from image 53 extracted and saved!
# Face from image 54 extracted and saved!
# Face from image 55 extracted and saved!
# Face from image 56 extracted and saved!
# Face from image 57 extracted and saved!
# Face from image 58 extracted and saved!
# Face from image 59 extracted and saved!
# Face from image 60 extracted and saved!
# Face from image 61 extracted and saved!
# Face from image 62 extracted and saved!
# Face from image 63 extracted and saved!
# Face from image 64 extracted and saved!
# Face from image 65 extracted and saved!
# Face from image 66 extracted and saved!
# Face from image 67 extracted and saved!
# Face from image 68 extracted and saved!
# Face from image 69 extracted and saved!
# Face from image 70 extracted and saved!
# Face from image 71 extracted and saved!
# Face from image 72 extracted and saved!
# Face from image 73 extracted and saved!
# Face from image 74 extracted and saved!
# Face from image 75 extracted and saved!
# Face from image 76 extracted and saved!
# Face from image 77 extracted and saved!
# Face from image 78 extracted and saved!
# Face from image 79 extracted and saved!
# Face from image 80 extracted and saved!
# Face from image 81 extracted and saved!
# Face from image 82 extracted and saved!
# Face from image 83 extracted and saved!
# Face from image 84 extracted and saved!
# Face from image 85 extracted and saved!
# Face from image 86 extracted and saved!
# Face from image 87 extracted and saved!
# Face from image 88 extracted and saved!
# Face from image 89 extracted and saved!
# Face from image 90 extracted and saved!
# Face from image 91 extracted and saved!
# Face from image 92 extracted and saved!
# Face from image 93 extracted and saved!
# Face from image 94 extracted and saved!
# Face from image 95 extracted and saved!
# Face from image 96 extracted and saved!
# Face from image 97 extracted and saved!
# Face from image 98 extracted and saved!
# Face from image 99 extracted and saved!
# Face from image 100 extracted and saved!
# Face from image 101 extracted and saved!
# Face from image 102 extracted and saved!
# Face from image 103 extracted and saved!
# Face from image 104 extracted and saved!
# Face from image 105 extracted and saved!
# Face from image 106 extracted and saved!
# Face from image 107 extracted and saved!
# Face from image 108 extracted and saved!
# Face from image 109 extracted and saved!
# Face from image 110 extracted and saved!
# Face from image 111 extracted and saved!
# Face from image 112 extracted and saved!
# Face from image 113 extracted and saved!
# Face from image 114 extracted and saved!
# Face from image 115 extracted and saved!
# Face from image 116 extracted and saved!
# Face from image 117 extracted and saved!
# Face from image 118 extracted and saved!
# Face from image 119 extracted and saved!
# Face from image 120 extracted and saved!
# Face from image 121 extracted and saved!
# Face from image 122 extracted and saved!
# Face from image 123 extracted and saved!
# Face from image 124 extracted and saved!
# Face from image 125 extracted and saved!
# Face from image 126 extracted and saved!
# Face from image 127 extracted and saved!
# Face from image 128 extracted and saved!
# Face from image 129 extracted and saved!
# Face from image 130 extracted and saved!
# Face from image 131 extracted and saved!
# Face from image 132 extracted and saved!
# Face from image 133 extracted and saved!
# Face from image 134 extracted and saved!
# Face from image 135 extracted and saved!
# Face from image 136 extracted and saved!
# Face from image 137 extracted and saved!
# Face from image 138 extracted and saved!
# Face from image 139 extracted and saved!
# Face from image 140 extracted and saved!
# Face from image 141 extracted and saved!
# Face from image 142 extracted and saved!
# Face from image 143 extracted and saved!
# Face from image 144 extracted and saved!
# Face from image 145 extracted and saved!
# Face from image 146 extracted and saved!
# Face from image 147 extracted and saved!
# Face from image 148 extracted and saved!
# Face from image 149 extracted and saved!
# Face from image 150 extracted and saved!
# Face from image 151 extracted and saved!
# Face from image 152 extracted and saved!
# Face from image 153 extracted and saved!
# Face from image 154 extracted and saved!
# Face from image 155 extracted and saved!
# Face from image 156 extracted and saved!
# Face from image 157 extracted and saved!
# Face from image 158 extracted and saved!
# Face from image 159 extracted and saved!
# Face from image 160 extracted and saved!
# Face from image 161 extracted and saved!
# Face from image 162 extracted and saved!
# Face from image 163 extracted and saved!
# Face from image 164 extracted and saved!
# Face from image 165 extracted and saved!
# Face from image 166 extracted and saved!
# Face from image 167 extracted and saved!
# Face from image 168 extracted and saved!
# Face from image 169 extracted and saved!
# Face from image 170 extracted and saved!
# Face from image 171 extracted and saved!
# Face from image 172 extracted and saved!
# Face from image 173 extracted and saved!
# Face from image 174 extracted and saved!
# Face from image 175 extracted and saved!
# Face from image 176 extracted and saved!
# Face from image 177 extracted and saved!
# Face from image 178 extracted and saved!
# Face from image 179 extracted and saved!
# Face from image 180 extracted and saved!
# Face from image 181 extracted and saved!
# Face from image 182 extracted and saved!
# Face from image 183 extracted and saved!
# Face from image 184 extracted and saved!
# Face from image 185 extracted and saved!
# Face from image 186 extracted and saved!
# Face from image 187 extracted and saved!
# Face from image 188 extracted and saved!
# Face from image 189 extracted and saved!
# Face from image 190 extracted and saved!
# Face from image 191 extracted and saved!
# Face from image 192 extracted and saved!
# Face from image 193 extracted and saved!
# Face from image 194 extracted and saved!
# Face from image 195 extracted and saved!
# Face from image 196 extracted and saved!
# Face from image 197 extracted and saved!
# Face from image 198 extracted and saved!
# Face from image 199 extracted and saved!
# Face from image 200 extracted and saved!
# Face from image 201 extracted and saved!
# Face from image 202 extracted and saved!
# Face from image 203 extracted and saved!
# Face from image 204 extracted and saved!
# Face from image 205 extracted and saved!
# Face from image 206 extracted and saved!
# Face from image 207 extracted and saved!
# Face from image 208 extracted and saved!
# Face from image 209 extracted and saved!
# Face from image 210 extracted and saved!
# Face from image 211 extracted and saved!
# Face from image 212 extracted and saved!
# Face from image 213 extracted and saved!
# Face from image 214 extracted and saved!
# Face from image 215 extracted and saved!
# Face from image 216 extracted and saved!
# Face from image 217 extracted and saved!
# Face from image 218 extracted and saved!
# Face from image 219 extracted and saved!
# Face from image 220 extracted and saved!
# Face from image 221 extracted and saved!
# Face from image 222 extracted and saved!
# Face from image 223 extracted and saved!
# Face from image 224 extracted and saved!
# Face from image 225 extracted and saved!
# Face from image 226 extracted and saved!
# Face from image 227 extracted and saved!
# Face from image 228 extracted and saved!
# Face from image 229 extracted and saved!
# Face from image 230 extracted and saved!
# Face from image 231 extracted and saved!
# Face from image 232 extracted and saved!
# Face from image 233 extracted and saved!
# Face from image 234 extracted and saved!
# Face from image 235 extracted and saved!
# Face from image 236 extracted and saved!
# Face from image 237 extracted and saved!
# Face from image 238 extracted and saved!
# Face from image 239 extracted and saved!
# Face from image 240 extracted and saved!
# Face from image 241 extracted and saved!
# Face from image 242 extracted and saved!
# Face from image 243 extracted and saved!
# Face from image 244 extracted and saved!
# Face from image 245 extracted and saved!
# Face from image 246 extracted and saved!
# Face from image 247 extracted and saved!
# Face from image 248 extracted and saved!
# Face from image 249 extracted and saved!
# Face from image 250 extracted and saved!
# Face from image 251 extracted and saved!
# Face from image 252 extracted and saved!
# Face from image 253 extracted and saved!
# Face from image 254 extracted and saved!
# Face from image 255 extracted and saved!
# Face from image 256 extracted and saved!
# Face from image 257 extracted and saved!
# Face from image 258 extracted and saved!
# Face from image 259 extracted and saved!
# Face from image 260 extracted and saved!
# Face from image 261 extracted and saved!
# Face from image 262 extracted and saved!
# Face from image 263 extracted and saved!
# Face from image 264 extracted and saved!
# Face from image 265 extracted and saved!
# Face from image 266 extracted and saved!
# Face from image 267 extracted and saved!
# Face from image 268 extracted and saved!
# Face from image 269 extracted and saved!
# Face from image 270 extracted and saved!
# Face from image 271 extracted and saved!
# Face from image 272 extracted and saved!
# Face from image 273 extracted and saved!
# Face from image 274 extracted and saved!
# Face from image 275 extracted and saved!
# Face from image 276 extracted and saved!
# Face from image 277 extracted and saved!
# Face from image 278 extracted and saved!
# Face from image 279 extracted and saved!
# Face from image 280 extracted and saved!
# [array([[[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [138, 173, 116],
#          [138, 173, 116],
#          [138, 173, 116]],
#
#         [[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [138, 173, 116],
#          [138, 173, 116],
#          [138, 173, 116]],
#
#         [[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [138, 173, 116],
#          [138, 173, 116],
#          [138, 173, 116]],
#
#         ...,
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 36,  35,  69],
#          [ 36,  35,  69],
#          [ 36,  35,  69]],
#
#         [[138, 167, 111],
#          [138, 167, 111],
#          [138, 167, 111],
#          ...,
#          [ 35,  34,  69],
#          [ 35,  34,  69],
#          [ 35,  34,  69]],
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 35,  33,  69],
#          [ 35,  33,  69],
#          [ 35,  33,  69]]], dtype=uint8), array([[[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [140, 173, 116],
#          [139, 173, 116],
#          [138, 173, 116]],
#
#         [[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [139, 173, 116],
#          [139, 173, 116]],
#
#         [[139, 173, 112],
#          [139, 173, 112],
#          [139, 173, 112],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         ...,
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 37,  34,  66],
#          [ 36,  34,  66],
#          [ 35,  34,  66]],
#
#         [[136, 166, 110],
#          [136, 166, 110],
#          [136, 166, 110],
#          ...,
#          [ 36,  34,  66],
#          [ 36,  34,  66],
#          [ 35,  34,  66]],
#
#         [[135, 167, 110],
#          [135, 167, 110],
#          [135, 167, 110],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  67],
#          [ 36,  35,  67]]], dtype=uint8), array([[[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         ...,
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 35,  34,  68],
#          [ 35,  33,  68],
#          [ 35,  33,  69]],
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 35,  34,  69],
#          [ 35,  33,  70],
#          [ 35,  33,  70]],
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 36,  34,  70],
#          [ 36,  33,  71],
#          [ 36,  33,  72]]], dtype=uint8), array([[[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         ...,
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 33,  32,  64],
#          [ 33,  32,  64],
#          [ 34,  33,  65]],
#
#         [[138, 167, 111],
#          [138, 167, 111],
#          [138, 167, 111],
#          ...,
#          [ 33,  32,  66],
#          [ 34,  33,  66],
#          [ 34,  33,  66]],
#
#         [[137, 166, 110],
#          [137, 166, 110],
#          [137, 166, 110],
#          ...,
#          [ 34,  33,  67],
#          [ 34,  33,  67],
#          [ 34,  33,  67]]], dtype=uint8), array([[[139, 173, 112],
#          [139, 173, 112],
#          [139, 173, 112],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 173, 111],
#          [139, 173, 111],
#          [139, 173, 112],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[139, 174, 110],
#          [139, 173, 111],
#          [139, 173, 112],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         ...,
#
#         [[141, 167, 113],
#          [141, 167, 113],
#          [141, 167, 113],
#          ...,
#          [ 33,  32,  64],
#          [ 33,  32,  64],
#          [ 33,  32,  64]],
#
#         [[140, 167, 112],
#          [140, 167, 112],
#          [141, 167, 112],
#          ...,
#          [ 33,  32,  64],
#          [ 33,  32,  64],
#          [ 33,  32,  64]],
#
#         [[139, 168, 112],
#          [140, 168, 112],
#          [141, 168, 112],
#          ...,
#          [ 33,  32,  64],
#          [ 33,  32,  64],
#          [ 33,  32,  64]]], dtype=uint8), array([[[140, 172, 113],
#          [140, 172, 113],
#          [140, 172, 113],
#          ...,
#          [143, 172, 117],
#          [143, 172, 117],
#          [143, 172, 117]],
#
#         [[140, 172, 113],
#          [140, 172, 113],
#          [139, 172, 112],
#          ...,
#          [143, 172, 117],
#          [143, 172, 117],
#          [143, 172, 117]],
#
#         [[140, 172, 113],
#          [139, 171, 112],
#          [139, 171, 112],
#          ...,
#          [143, 172, 117],
#          [143, 172, 117],
#          [143, 172, 117]],
#
#         ...,
#
#         [[137, 169, 110],
#          [137, 169, 110],
#          [137, 169, 110],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[137, 169, 110],
#          [137, 169, 110],
#          [137, 169, 110],
#          ...,
#          [ 34,  33,  65],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[137, 169, 110],
#          [137, 169, 110],
#          [137, 169, 110],
#          ...,
#          [ 34,  33,  65],
#          [ 34,  33,  65],
#          [ 35,  34,  66]]], dtype=uint8), array([[[140, 172, 113],
#          [140, 172, 113],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [141, 171, 119],
#          [142, 172, 119]],
#
#         [[140, 172, 113],
#          [140, 172, 113],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [142, 171, 118],
#          [142, 172, 119]],
#
#         [[140, 172, 113],
#          [140, 172, 113],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [141, 171, 118],
#          [142, 172, 119]],
#
#         ...,
#
#         [[139, 168, 112],
#          [140, 168, 112],
#          [141, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[139, 168, 112],
#          [140, 168, 112],
#          [141, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[139, 168, 112],
#          [140, 168, 112],
#          [141, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]]], dtype=uint8), array([[[140, 172, 115],
#          [140, 172, 114],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [140, 171, 118],
#          [140, 172, 118]],
#
#         [[140, 172, 115],
#          [140, 172, 114],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [140, 171, 118],
#          [140, 172, 118]],
#
#         [[140, 172, 115],
#          [140, 172, 114],
#          [140, 172, 113],
#          ...,
#          [141, 171, 118],
#          [140, 171, 118],
#          [140, 172, 118]],
#
#         ...,
#
#         [[141, 168, 112],
#          [140, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[141, 168, 112],
#          [140, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[141, 168, 112],
#          [140, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]]], dtype=uint8), array([[[138, 172, 112],
#          [138, 172, 112],
#          [139, 173, 113],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[138, 172, 112],
#          [139, 173, 112],
#          [139, 173, 113],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[139, 173, 112],
#          [139, 173, 112],
#          [140, 174, 113],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         ...,
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [ 35,  35,  67],
#          [ 35,  35,  67],
#          [ 35,  35,  67]],
#
#         [[139, 168, 112],
#          [138, 168, 112],
#          [138, 168, 112],
#          ...,
#          [ 35,  34,  66],
#          [ 35,  34,  66],
#          [ 35,  34,  66]],
#
#         [[139, 168, 112],
#          [138, 168, 112],
#          [137, 169, 112],
#          ...,
#          [ 34,  33,  65],
#          [ 34,  33,  65],
#          [ 34,  33,  65]]], dtype=uint8), array([[[139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 113],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[138, 172, 112],
#          [138, 172, 112],
#          [138, 172, 112],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[138, 172, 112],
#          [138, 172, 112],
#          [138, 172, 112],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         ...,
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 35,  34,  65],
#          [ 35,  35,  65],
#          [ 35,  35,  65]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 35,  35,  65],
#          [ 35,  35,  65],
#          [ 35,  35,  65]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 35,  35,  65],
#          [ 35,  35,  65],
#          [ 35,  35,  65]]], dtype=uint8), array([[[138, 172, 112],
#          [138, 172, 112],
#          [138, 172, 112],
#          ...,
#          [139, 172, 115],
#          [139, 172, 115],
#          [139, 172, 115]],
#
#         [[138, 172, 111],
#          [138, 172, 111],
#          [138, 172, 111],
#          ...,
#          [139, 172, 115],
#          [139, 172, 115],
#          [139, 172, 115]],
#
#         [[138, 172, 111],
#          [138, 172, 111],
#          [138, 172, 111],
#          ...,
#          [139, 172, 115],
#          [139, 172, 115],
#          [139, 172, 115]],
#
#         ...,
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 35,  36,  66],
#          [ 34,  35,  65],
#          [ 33,  35,  65]],
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 36,  36,  66],
#          [ 34,  36,  66],
#          [ 33,  35,  65]],
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 36,  36,  66],
#          [ 35,  36,  66],
#          [ 34,  36,  66]]], dtype=uint8), array([[[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [143, 172, 117],
#          [142, 172, 117],
#          [141, 172, 117]],
#
#         [[139, 173, 112],
#          [140, 173, 113],
#          [140, 173, 113],
#          ...,
#          [141, 171, 116],
#          [140, 171, 116],
#          [139, 171, 116]],
#
#         [[139, 172, 111],
#          [139, 172, 111],
#          [140, 172, 112],
#          ...,
#          [139, 170, 115],
#          [138, 170, 115],
#          [138, 170, 115]],
#
#         ...,
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 32,  34,  64],
#          [ 33,  34,  64],
#          [ 33,  35,  65]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 32,  34,  64],
#          [ 33,  35,  65],
#          [ 33,  35,  65]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 33,  35,  65],
#          [ 33,  35,  65],
#          [ 33,  35,  65]]], dtype=uint8), array([[[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [137, 169, 113],
#          [136, 168, 111],
#          [135, 167, 110]],
#
#         [[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [138, 169, 112],
#          [137, 167, 111],
#          [136, 166, 110]],
#
#         [[142, 171, 115],
#          [142, 171, 115],
#          [142, 171, 115],
#          ...,
#          [139, 169, 113],
#          [138, 167, 111],
#          [137, 166, 110]],
#
#         ...,
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 37,  41,  78],
#          [ 39,  42,  80],
#          [ 40,  43,  80]],
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 38,  42,  79],
#          [ 40,  42,  81],
#          [ 41,  43,  82]],
#
#         [[139, 168, 112],
#          [139, 168, 112],
#          [139, 168, 112],
#          ...,
#          [ 40,  43,  81],
#          [ 41,  43,  82],
#          [ 42,  44,  84]]], dtype=uint8), array([[[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [135, 167, 110],
#          [119, 149,  94],
#          [106, 135,  80]],
#
#         [[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [135, 167, 110],
#          [119, 149,  93],
#          [106, 135,  80]],
#
#         [[140, 174, 115],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [135, 167, 110],
#          [119, 149,  94],
#          [106, 135,  80]],
#
#         ...,
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 32,  36,  65],
#          [ 32,  36,  65],
#          [ 32,  36,  65]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 32,  36,  65],
#          [ 32,  36,  65],
#          [ 32,  36,  65]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [ 32,  36,  65],
#          [ 32,  36,  65],
#          [ 32,  36,  65]]], dtype=uint8), array([[[139, 175, 115],
#          [139, 175, 114],
#          [139, 176, 114],
#          ...,
#          [140, 174, 114],
#          [140, 173, 115],
#          [140, 173, 116]],
#
#         [[139, 175, 115],
#          [139, 175, 114],
#          [139, 176, 114],
#          ...,
#          [140, 174, 114],
#          [140, 173, 115],
#          [140, 173, 116]],
#
#         [[139, 175, 115],
#          [139, 175, 115],
#          [139, 176, 114],
#          ...,
#          [140, 174, 114],
#          [140, 173, 115],
#          [140, 173, 116]],
#
#         ...,
#
#         [[137, 169, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 48,  51,  79],
#          [ 49,  52,  80],
#          [ 50,  53,  80]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 48,  51,  79],
#          [ 49,  52,  80],
#          [ 49,  53,  81]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [ 49,  52,  80],
#          [ 48,  52,  80],
#          [ 48,  52,  80]]], dtype=uint8), array([[[128, 152, 122],
#          [110, 133, 106],
#          [ 88, 110,  87],
#          ...,
#          [140, 172, 115],
#          [140, 172, 115],
#          [140, 172, 115]],
#
#         [[110, 133, 107],
#          [ 92, 113,  90],
#          [ 70,  90,  70],
#          ...,
#          [140, 172, 115],
#          [140, 172, 115],
#          [140, 172, 115]],
#
#         [[ 85, 106,  85],
#          [ 69,  88,  70],
#          [ 49,  67,  53],
#          ...,
#          [139, 172, 115],
#          [140, 172, 115],
#          [140, 172, 115]],
#
#         ...,
#
#         [[140, 169, 113],
#          [140, 169, 113],
#          [140, 169, 113],
#          ...,
#          [122, 151, 106],
#          [122, 151, 106],
#          [122, 151, 106]],
#
#         [[140, 169, 113],
#          [140, 169, 113],
#          [140, 169, 113],
#          ...,
#          [121, 150, 105],
#          [121, 150, 105],
#          [121, 150, 105]],
#
#         [[140, 169, 113],
#          [140, 169, 113],
#          [140, 169, 113],
#          ...,
#          [121, 150, 105],
#          [121, 150, 105],
#          [121, 150, 105]]], dtype=uint8), array([[[ 44,  45,  66],
#          [ 44,  44,  66],
#          [ 43,  44,  65],
#          ...,
#          [121, 143, 118],
#          [123, 147, 119],
#          [124, 150, 120]],
#
#         [[ 42,  43,  64],
#          [ 42,  43,  64],
#          [ 41,  42,  63],
#          ...,
#          [119, 141, 117],
#          [122, 146, 120],
#          [124, 149, 122]],
#
#         [[ 39,  41,  62],
#          [ 39,  40,  61],
#          [ 39,  39,  60],
#          ...,
#          [116, 137, 114],
#          [119, 143, 118],
#          [122, 147, 121]],
#
#         ...,
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [120, 149, 104],
#          [120, 149, 104],
#          [120, 149, 104]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [120, 149, 104],
#          [120, 149, 104],
#          [120, 149, 104]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [120, 149, 104],
#          [120, 149, 104],
#          [120, 149, 104]]], dtype=uint8), array([[[ 34,  36,  60],
#          [ 32,  34,  59],
#          [ 30,  31,  57],
#          ...,
#          [111, 127, 109],
#          [116, 135, 114],
#          [120, 140, 117]],
#
#         [[ 31,  33,  57],
#          [ 31,  32,  57],
#          [ 29,  30,  56],
#          ...,
#          [108, 124, 107],
#          [113, 131, 110],
#          [117, 136, 112]],
#
#         [[ 30,  32,  55],
#          [ 29,  31,  55],
#          [ 29,  30,  55],
#          ...,
#          [104, 120, 103],
#          [109, 126, 106],
#          [113, 131, 108]],
#
#         ...,
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [119, 149, 100],
#          [119, 149, 100],
#          [119, 149, 100]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [118, 148, 100],
#          [118, 148, 100],
#          [118, 148, 100]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [118, 148,  99],
#          [118, 148,  99],
#          [118, 148,  99]]], dtype=uint8), array([[[ 33,  42,  55],
#          [ 33,  41,  57],
#          [ 34,  41,  60],
#          ...,
#          [132, 164, 117],
#          [133, 166, 116],
#          [134, 167, 116]],
#
#         [[ 33,  42,  56],
#          [ 33,  42,  57],
#          [ 34,  42,  59],
#          ...,
#          [135, 163, 121],
#          [137, 167, 122],
#          [139, 169, 122]],
#
#         [[ 34,  43,  57],
#          [ 34,  42,  58],
#          [ 34,  41,  59],
#          ...,
#          [129, 155, 118],
#          [134, 161, 121],
#          [137, 165, 123]],
#
#         ...,
#
#         [[138, 170, 111],
#          [138, 170, 112],
#          [138, 170, 113],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[138, 170, 111],
#          [138, 170, 112],
#          [138, 170, 113],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[138, 170, 111],
#          [138, 170, 112],
#          [138, 170, 113],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]]], dtype=uint8), array([[[ 39,  41,  71],
#          [ 39,  41,  70],
#          [ 38,  40,  70],
#          ...,
#          [ 31,  44,  42],
#          [ 33,  47,  42],
#          [ 35,  50,  42]],
#
#         [[ 39,  41,  71],
#          [ 38,  40,  70],
#          [ 37,  39,  69],
#          ...,
#          [ 31,  43,  44],
#          [ 32,  46,  43],
#          [ 34,  48,  43]],
#
#         [[ 38,  41,  70],
#          [ 38,  40,  69],
#          [ 37,  39,  68],
#          ...,
#          [ 35,  46,  49],
#          [ 35,  47,  47],
#          [ 35,  48,  46]],
#
#         ...,
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [119, 146, 103],
#          [120, 145, 103],
#          [121, 145, 103]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [119, 146, 103],
#          [120, 146, 103],
#          [120, 145, 103]],
#
#         [[138, 170, 113],
#          [138, 170, 113],
#          [138, 170, 113],
#          ...,
#          [119, 146, 103],
#          [119, 146, 103],
#          [119, 146, 103]]], dtype=uint8), array([[[ 38,  41,  69],
#          [ 39,  42,  70],
#          [ 41,  44,  72],
#          ...,
#          [137, 173, 113],
#          [138, 174, 113],
#          [138, 174, 114]],
#
#         [[ 37,  39,  68],
#          [ 37,  41,  68],
#          [ 39,  42,  70],
#          ...,
#          [138, 173, 113],
#          [138, 173, 113],
#          [139, 173, 113]],
#
#         [[ 34,  37,  65],
#          [ 35,  38,  66],
#          [ 38,  41,  67],
#          ...,
#          [139, 173, 113],
#          [139, 173, 113],
#          [139, 173, 112]],
#
#         ...,
#
#         [[129, 159, 123],
#          [112, 139, 116],
#          [ 89, 109, 106],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[128, 157, 125],
#          [112, 138, 118],
#          [ 89, 110, 109],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[127, 154, 128],
#          [113, 137, 122],
#          [ 93, 113, 115],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]]], dtype=uint8), array([[[ 36,  36,  60],
#          [ 36,  36,  60],
#          [ 37,  37,  61],
#          ...,
#          [136, 156, 127],
#          [137, 159, 127],
#          [137, 161, 127]],
#
#         [[ 38,  38,  62],
#          [ 38,  38,  62],
#          [ 39,  39,  62],
#          ...,
#          [135, 154, 129],
#          [136, 157, 129],
#          [137, 160, 129]],
#
#         [[ 39,  39,  62],
#          [ 39,  39,  61],
#          [ 39,  40,  61],
#          ...,
#          [133, 151, 129],
#          [135, 156, 130],
#          [137, 159, 131]],
#
#         ...,
#
#         [[ 64,  77, 123],
#          [ 64,  77, 123],
#          [ 64,  77, 124],
#          ...,
#          [119, 148, 103],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[ 64,  77, 123],
#          [ 64,  77, 123],
#          [ 64,  77, 123],
#          ...,
#          [119, 148, 103],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[ 64,  77, 123],
#          [ 64,  77, 123],
#          [ 64,  77, 123],
#          ...,
#          [119, 148, 103],
#          [118, 147, 102],
#          [118, 147, 102]]], dtype=uint8), array([[[ 24,  27,  48],
#          [ 23,  26,  47],
#          [ 22,  25,  46],
#          ...,
#          [138, 170, 115],
#          [138, 171, 114],
#          [138, 171, 114]],
#
#         [[ 27,  30,  51],
#          [ 27,  30,  51],
#          [ 26,  29,  50],
#          ...,
#          [137, 169, 115],
#          [137, 169, 114],
#          [137, 170, 114]],
#
#         [[ 32,  35,  56],
#          [ 32,  35,  56],
#          [ 32,  35,  56],
#          ...,
#          [137, 168, 115],
#          [137, 168, 115],
#          [137, 169, 114]],
#
#         ...,
#
#         [[ 63,  77, 126],
#          [ 63,  77, 127],
#          [ 63,  76, 128],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[ 63,  77, 126],
#          [ 63,  76, 126],
#          [ 62,  76, 127],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[ 63,  77, 126],
#          [ 63,  76, 126],
#          [ 62,  75, 127],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]]], dtype=uint8), array([[[ 36,  39,  60],
#          [ 37,  40,  61],
#          [ 39,  42,  63],
#          ...,
#          [140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114]],
#
#         [[ 30,  33,  54],
#          [ 31,  34,  55],
#          [ 32,  35,  56],
#          ...,
#          [139, 173, 114],
#          [140, 173, 114],
#          [140, 174, 114]],
#
#         [[ 24,  27,  48],
#          [ 24,  27,  48],
#          [ 24,  27,  48],
#          ...,
#          [139, 171, 115],
#          [139, 172, 115],
#          [139, 173, 115]],
#
#         ...,
#
#         [[ 69,  78, 128],
#          [ 68,  78, 128],
#          [ 67,  78, 128],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 147, 102]],
#
#         [[ 69,  79, 128],
#          [ 68,  78, 128],
#          [ 67,  78, 128],
#          ...,
#          [118, 147, 102],
#          [118, 147, 102],
#          [118, 146, 102]],
#
#         [[ 70,  80, 128],
#          [ 69,  79, 128],
#          [ 67,  79, 127],
#          ...,
#          [118, 147, 102],
#          [118, 146, 103],
#          [118, 146, 103]]], dtype=uint8), array([[[ 32,  37,  62],
#          [ 31,  37,  61],
#          [ 31,  37,  60],
#          ...,
#          [138, 173, 117],
#          [137, 173, 116],
#          [136, 174, 116]],
#
#         [[ 31,  37,  61],
#          [ 31,  37,  60],
#          [ 31,  37,  59],
#          ...,
#          [139, 173, 116],
#          [138, 174, 115],
#          [137, 174, 115]],
#
#         [[ 31,  38,  59],
#          [ 31,  38,  59],
#          [ 31,  38,  58],
#          ...,
#          [140, 173, 115],
#          [139, 174, 114],
#          [139, 174, 114]],
#
#         ...,
#
#         [[ 83,  98, 114],
#          [ 80,  94, 115],
#          [ 76,  87, 116],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 102]],
#
#         [[ 84, 100, 115],
#          [ 81,  95, 115],
#          [ 77,  88, 116],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]],
#
#         [[ 85, 101, 114],
#          [ 81,  95, 114],
#          [ 77,  88, 115],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]]], dtype=uint8), array([[[140, 173, 116],
#          [139, 172, 115],
#          [139, 172, 115],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[141, 174, 116],
#          [140, 173, 116],
#          [140, 173, 116],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         [[141, 173, 117],
#          [141, 173, 117],
#          [140, 173, 117],
#          ...,
#          [140, 172, 117],
#          [140, 172, 117],
#          [140, 172, 117]],
#
#         ...,
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [116, 148,  99],
#          [116, 148,  99],
#          [116, 148,  99]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [115, 148,  99],
#          [115, 148,  99],
#          [115, 148,  99]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [114, 149,  99],
#          [114, 149,  99],
#          [114, 149,  99]]], dtype=uint8), array([[[130, 156, 126],
#          [127, 153, 125],
#          [124, 149, 123],
#          ...,
#          [138, 170, 123],
#          [138, 170, 122],
#          [139, 171, 122]],
#
#         [[127, 152, 125],
#          [123, 147, 123],
#          [117, 140, 119],
#          ...,
#          [137, 169, 123],
#          [138, 170, 123],
#          [138, 170, 122]],
#
#         [[116, 140, 118],
#          [110, 133, 113],
#          [100, 122, 106],
#          ...,
#          [137, 167, 123],
#          [137, 169, 123],
#          [138, 169, 122]],
#
#         ...,
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [120, 147, 103],
#          [120, 147, 103],
#          [120, 147, 103]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [120, 147, 103],
#          [120, 147, 103],
#          [120, 147, 103]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [120, 147, 103],
#          [120, 147, 103],
#          [120, 147, 103]]], dtype=uint8), array([[[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 83, 102,  93],
#          [102, 122, 109],
#          [115, 136, 121]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 65,  83,  77],
#          [ 82, 101,  91],
#          [ 93, 113, 101]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 45,  61,  58],
#          [ 56,  73,  68],
#          [ 64,  82,  75]],
#
#         ...,
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [122, 147, 105],
#          [122, 147, 105],
#          [122, 147, 105]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [123, 147, 105],
#          [123, 147, 105],
#          [123, 147, 105]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [123, 147, 105],
#          [123, 147, 105],
#          [123, 147, 105]]], dtype=uint8), array([[[142, 174, 117],
#          [142, 174, 117],
#          [142, 174, 117],
#          ...,
#          [ 41,  53,  55],
#          [ 40,  54,  53],
#          [ 40,  55,  51]],
#
#         [[142, 174, 117],
#          [142, 174, 117],
#          [142, 174, 117],
#          ...,
#          [ 38,  50,  53],
#          [ 41,  53,  53],
#          [ 42,  56,  54]],
#
#         [[142, 174, 117],
#          [142, 174, 117],
#          [142, 174, 117],
#          ...,
#          [ 37,  47,  53],
#          [ 40,  51,  54],
#          [ 42,  54,  55]],
#
#         ...,
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [121, 148, 105],
#          [121, 148, 105],
#          [121, 148, 105]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [121, 148, 104],
#          [121, 148, 104],
#          [121, 148, 104]],
#
#         [[137, 169, 112],
#          [137, 169, 112],
#          [137, 169, 112],
#          ...,
#          [120, 147, 103],
#          [120, 147, 103],
#          [120, 147, 103]]], dtype=uint8), array([[[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [ 39,  55,  48],
#          [ 59,  76,  65],
#          [ 74,  92,  79]],
#
#         [[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [ 37,  52,  48],
#          [ 48,  65,  57],
#          [ 57,  75,  64]],
#
#         [[140, 174, 114],
#          [140, 174, 114],
#          [140, 174, 114],
#          ...,
#          [ 37,  51,  49],
#          [ 41,  56,  51],
#          [ 44,  61,  53]],
#
#         ...,
#
#         [[136, 168, 111],
#          [136, 168, 111],
#          [136, 168, 111],
#          ...,
#          [120, 147, 104],
#          [120, 147, 104],
#          [120, 147, 104]],
#
#         [[135, 167, 110],
#          [135, 167, 110],
#          [135, 167, 110],
#          ...,
#          [120, 147, 104],
#          [120, 147, 104],
#          [120, 147, 104]],
#
#         [[135, 167, 110],
#          [135, 167, 110],
#          [135, 167, 110],
#          ...,
#          [120, 147, 104],
#          [120, 147, 104],
#          [120, 147, 104]]], dtype=uint8), array([[[134, 159, 121],
#          [134, 157, 123],
#          [133, 155, 126],
#          ...,
#          [ 48,  62,  61],
#          [ 46,  59,  58],
#          [ 44,  58,  56]],
#
#         [[129, 152, 118],
#          [125, 148, 117],
#          [120, 142, 115],
#          ...,
#          [ 51,  63,  66],
#          [ 48,  61,  62],
#          [ 46,  60,  60]],
#
#         [[125, 148, 118],
#          [119, 141, 113],
#          [109, 129, 106],
#          ...,
#          [ 51,  62,  68],
#          [ 48,  60,  64],
#          [ 46,  59,  62]],
#
#         ...,
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [119, 147, 104],
#          [119, 147, 104],
#          [119, 147, 104]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [118, 147, 104],
#          [119, 147, 104],
#          [119, 147, 104]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [117, 147, 104],
#          [118, 147, 104],
#          [119, 147, 104]]], dtype=uint8), array([[[125, 144, 125],
#          [113, 131, 115],
#          [ 95, 112,  99],
#          ...,
#          [125, 150, 116],
#          [129, 155, 118],
#          [132, 159, 119]],
#
#         [[113, 130, 113],
#          [101, 117, 105],
#          [ 85, 100,  91],
#          ...,
#          [117, 141, 109],
#          [123, 149, 114],
#          [128, 154, 117]],
#
#         [[ 97, 112,  99],
#          [ 86, 101,  91],
#          [ 71,  84,  79],
#          ...,
#          [109, 132, 104],
#          [118, 142, 110],
#          [124, 149, 114]],
#
#         ...,
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [120, 148, 105],
#          [120, 148, 105],
#          [120, 148, 105]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [119, 148, 104],
#          [119, 148, 104],
#          [120, 148, 104]],
#
#         [[139, 168, 113],
#          [139, 168, 113],
#          [139, 168, 113],
#          ...,
#          [117, 147, 104],
#          [118, 147, 104],
#          [119, 147, 104]]], dtype=uint8), array([[[135, 162, 122],
#          [134, 160, 122],
#          [133, 157, 123],
#          ...,
#          [136, 171, 115],
#          [136, 171, 115],
#          [137, 172, 116]],
#
#         [[131, 156, 120],
#          [127, 152, 118],
#          [122, 145, 115],
#          ...,
#          [136, 170, 115],
#          [137, 171, 116],
#          [137, 172, 116]],
#
#         [[124, 148, 116],
#          [118, 141, 112],
#          [110, 130, 105],
#          ...,
#          [136, 170, 116],
#          [137, 171, 116],
#          [137, 172, 117]],
#
#         ...,
#
#         [[136, 169, 112],
#          [136, 169, 112],
#          [136, 169, 112],
#          ...,
#          [120, 148, 105],
#          [120, 148, 105],
#          [120, 148, 105]],
#
#         [[136, 169, 112],
#          [136, 169, 112],
#          [136, 169, 112],
#          ...,
#          [120, 148, 105],
#          [120, 148, 105],
#          [120, 148, 105]],
#
#         [[136, 169, 112],
#          [136, 169, 112],
#          [136, 169, 112],
#          ...,
#          [120, 148, 105],
#          [120, 148, 105],
#          [120, 148, 105]]], dtype=uint8), array([[[ 32,  45,  43],
#          [ 31,  44,  43],
#          [ 29,  42,  44],
#          ...,
#          [138, 172, 118],
#          [139, 172, 118],
#          [140, 172, 118]],
#
#         [[ 30,  42,  43],
#          [ 29,  42,  44],
#          [ 29,  41,  46],
#          ...,
#          [138, 172, 118],
#          [139, 172, 118],
#          [140, 173, 118]],
#
#         [[ 29,  41,  44],
#          [ 29,  40,  45],
#          [ 28,  39,  47],
#          ...,
#          [138, 172, 118],
#          [140, 173, 119],
#          [141, 173, 119]],
#
#         ...,
#
#         [[136, 169, 112],
#          [136, 168, 111],
#          [137, 166, 111],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]],
#
#         [[136, 169, 112],
#          [136, 168, 112],
#          [137, 166, 111],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]],
#
#         [[136, 169, 112],
#          [136, 168, 111],
#          [137, 166, 111],
#          ...,
#          [118, 146, 103],
#          [118, 146, 103],
#          [118, 146, 103]]], dtype=uint8), array([[[ 28,  35,  52],
# ...
#          [144, 174, 115],
#          [144, 174, 115],
#          ...,
#          [ 40,  43,  58],
#          [ 37,  40,  55],
#          [ 35,  38,  53]],
#
#         [[144, 174, 115],
#          [144, 174, 115],
#          [144, 174, 115],
#          ...,
#          [ 40,  44,  58],
#          [ 38,  40,  55],
#          [ 36,  38,  53]],
#
#         [[144, 174, 115],
#          [144, 174, 115],
#          [144, 174, 115],
#          ...,
#          [ 40,  44,  59],
#          [ 38,  41,  56],
#          [ 36,  39,  54]],
#
#         ...,
#
#         [[ 71,  82, 142],
#          [ 71,  81, 141],
#          [ 71,  81, 141],
#          ...,
#          [121, 145, 103],
#          [121, 145, 103],
#          [121, 145, 103]],
#
#         [[ 71,  81, 141],
#          [ 71,  81, 141],
#          [ 71,  81, 141],
#          ...,
#          [121, 145, 103],
#          [121, 145, 103],
#          [121, 145, 103]],
#
#         [[ 71,  81, 141],
#          [ 71,  81, 141],
#          [ 71,  81, 141],
#          ...,
#          [121, 145, 103],
#          [121, 145, 103],
#          [121, 145, 103]]], dtype=uint8), array([[[147, 177, 118],
#          [147, 177, 118],
#          [147, 177, 118],
#          ...,
#          [ 36,  39,  53],
#          [ 34,  37,  51],
#          [ 33,  36,  50]],
#
#         [[146, 176, 117],
#          [147, 177, 118],
#          [147, 177, 118],
#          ...,
#          [ 38,  41,  56],
#          [ 36,  39,  53],
#          [ 34,  37,  51]],
#
#         [[146, 176, 117],
#          [146, 176, 117],
#          [146, 176, 117],
#          ...,
#          [ 41,  44,  59],
#          [ 38,  41,  56],
#          [ 36,  39,  53]],
#
#         ...,
#
#         [[ 71,  81, 141],
#          [ 70,  80, 140],
#          [ 70,  80, 139],
#          ...,
#          [119, 146, 103],
#          [119, 146, 102],
#          [119, 146, 102]],
#
#         [[ 71,  81, 141],
#          [ 71,  80, 141],
#          [ 70,  80, 140],
#          ...,
#          [119, 146, 102],
#          [119, 146, 102],
#          [119, 146, 102]],
#
#         [[ 71,  81, 141],
#          [ 71,  80, 140],
#          [ 70,  80, 140],
#          ...,
#          [119, 146, 102],
#          [119, 146, 102],
#          [119, 146, 102]]], dtype=uint8), array([[[142, 174, 115],
#          [143, 175, 116],
#          [144, 176, 117],
#          ...,
#          [144, 171, 121],
#          [142, 170, 119],
#          [140, 170, 117]],
#
#         [[142, 174, 115],
#          [143, 175, 116],
#          [144, 176, 117],
#          ...,
#          [144, 170, 121],
#          [142, 170, 120],
#          [141, 170, 119]],
#
#         [[142, 174, 115],
#          [143, 175, 116],
#          [144, 176, 117],
#          ...,
#          [142, 169, 121],
#          [142, 169, 120],
#          [141, 170, 120]],
#
#         ...,
#
#         [[ 68,  75, 135],
#          [ 68,  75, 134],
#          [ 68,  74, 133],
#          ...,
#          [118, 145, 101],
#          [119, 145, 102],
#          [119, 144, 102]],
#
#         [[ 68,  76, 136],
#          [ 68,  76, 135],
#          [ 69,  75, 134],
#          ...,
#          [118, 145, 101],
#          [119, 144, 101],
#          [120, 144, 102]],
#
#         [[ 68,  76, 136],
#          [ 69,  76, 136],
#          [ 70,  76, 135],
#          ...,
#          [118, 145, 101],
#          [119, 144, 102],
#          [120, 144, 102]]], dtype=uint8), array([[[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 31,  35,  46],
#          [ 29,  33,  43],
#          [ 27,  32,  41]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 30,  34,  47],
#          [ 28,  32,  44],
#          [ 27,  31,  42]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 30,  33,  47],
#          [ 28,  31,  44],
#          [ 26,  30,  42]],
#
#         ...,
#
#         [[ 70,  82, 141],
#          [ 70,  81, 141],
#          [ 70,  81, 141],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]],
#
#         [[ 71,  82, 142],
#          [ 71,  82, 142],
#          [ 71,  82, 142],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]],
#
#         [[ 72,  83, 143],
#          [ 72,  83, 143],
#          [ 72,  83, 143],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]]], dtype=uint8), array([[[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 35,  36,  50],
#          [ 33,  35,  47],
#          [ 32,  34,  45]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 35,  35,  51],
#          [ 33,  34,  48],
#          [ 31,  33,  46]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 35,  35,  52],
#          [ 33,  33,  48],
#          [ 31,  32,  46]],
#
#         ...,
#
#         [[ 72,  83, 145],
#          [ 72,  83, 144],
#          [ 71,  82, 142],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]],
#
#         [[ 71,  83, 145],
#          [ 71,  82, 143],
#          [ 71,  82, 142],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]],
#
#         [[ 71,  82, 144],
#          [ 71,  82, 143],
#          [ 71,  82, 142],
#          ...,
#          [116, 145, 100],
#          [116, 145, 100],
#          [116, 145, 100]]], dtype=uint8), array([[[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 23,  26,  34],
#          [ 22,  25,  33],
#          [ 22,  25,  33]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 21,  24,  32],
#          [ 20,  23,  31],
#          [ 19,  22,  30]],
#
#         [[144, 173, 117],
#          [144, 173, 117],
#          [144, 173, 117],
#          ...,
#          [ 20,  23,  32],
#          [ 19,  21,  30],
#          [ 17,  20,  29]],
#
#         ...,
#
#         [[ 71,  84, 143],
#          [ 70,  84, 143],
#          [ 68,  82, 141],
#          ...,
#          [117, 144, 100],
#          [117, 144, 100],
#          [117, 144, 100]],
#
#         [[ 71,  84, 144],
#          [ 70,  84, 143],
#          [ 69,  83, 142],
#          ...,
#          [116, 144, 100],
#          [117, 144, 100],
#          [117, 144, 100]],
#
#         [[ 70,  84, 143],
#          [ 70,  83, 142],
#          [ 69,  83, 142],
#          ...,
#          [116, 144, 101],
#          [117, 144, 101],
#          [117, 144, 101]]], dtype=uint8), array([[[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 88, 102,  82],
#          [106, 122,  98],
#          [119, 136, 109]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 68,  80,  63],
#          [ 86, 100,  79],
#          [ 98, 114,  91]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 47,  57,  44],
#          [ 60,  73,  57],
#          [ 71,  85,  67]],
#
#         ...,
#
#         [[ 68,  85, 142],
#          [ 68,  85, 142],
#          [ 67,  84, 141],
#          ...,
#          [117, 144, 100],
#          [117, 144, 100],
#          [117, 144, 100]],
#
#         [[ 68,  85, 142],
#          [ 68,  85, 142],
#          [ 68,  85, 142],
#          ...,
#          [117, 144, 100],
#          [117, 144, 100],
#          [117, 144, 100]],
#
#         [[ 68,  85, 142],
#          [ 68,  85, 142],
#          [ 68,  85, 142],
#          ...,
#          [117, 144, 100],
#          [117, 144, 100],
#          [117, 144, 100]]], dtype=uint8), array([[[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 24,  28,  29],
#          [ 24,  28,  29],
#          [ 25,  29,  30]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 25,  29,  32],
#          [ 25,  28,  31],
#          [ 24,  27,  31]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 26,  29,  33],
#          [ 25,  28,  34],
#          [ 24,  27,  34]],
#
#         ...,
#
#         [[ 73,  85, 143],
#          [ 73,  84, 143],
#          [ 73,  84, 144],
#          ...,
#          [117, 145, 102],
#          [116, 145, 102],
#          [115, 145, 102]],
#
#         [[ 73,  85, 142],
#          [ 73,  84, 143],
#          [ 72,  83, 144],
#          ...,
#          [117, 145, 102],
#          [116, 145, 102],
#          [115, 145, 102]],
#
#         [[ 72,  84, 142],
#          [ 72,  83, 142],
#          [ 72,  83, 143],
#          ...,
#          [117, 145, 102],
#          [116, 145, 102],
#          [115, 145, 102]]], dtype=uint8), array([[[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 37,  37,  49],
#          [ 34,  34,  46],
#          [ 32,  32,  44]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 38,  38,  50],
#          [ 36,  36,  48],
#          [ 34,  34,  46]],
#
#         [[143, 173, 114],
#          [143, 173, 114],
#          [143, 173, 114],
#          ...,
#          [ 39,  39,  52],
#          [ 37,  37,  50],
#          [ 37,  37,  49]],
#
#         ...,
#
#         [[ 70,  82, 130],
#          [ 69,  82, 130],
#          [ 68,  82, 130],
#          ...,
#          [116, 147, 102],
#          [116, 147, 102],
#          [116, 147, 102]],
#
#         [[ 70,  82, 130],
#          [ 69,  82, 130],
#          [ 68,  82, 131],
#          ...,
#          [116, 147, 102],
#          [116, 147, 102],
#          [116, 147, 102]],
#
#         [[ 70,  82, 130],
#          [ 69,  82, 131],
#          [ 69,  83, 132],
#          ...,
#          [116, 147, 102],
#          [116, 147, 102],
#          [116, 147, 102]]], dtype=uint8), array([[[141, 169, 116],
#          [140, 168, 116],
#          [140, 167, 117],
#          ...,
#          [ 35,  37,  48],
#          [ 33,  35,  46],
#          [ 32,  34,  45]],
#
#         [[138, 166, 115],
#          [138, 165, 114],
#          [137, 163, 114],
#          ...,
#          [ 38,  39,  52],
#          [ 37,  39,  50],
#          [ 36,  38,  49]],
#
#         [[135, 162, 113],
#          [135, 161, 113],
#          [133, 159, 112],
#          ...,
#          [ 41,  42,  56],
#          [ 40,  42,  55],
#          [ 40,  42,  54]],
#
#         ...,
#
#         [[ 73,  82, 125],
#          [ 72,  82, 126],
#          [ 71,  82, 126],
#          ...,
#          [119, 147, 101],
#          [119, 147, 101],
#          [119, 147, 101]],
#
#         [[ 72,  82, 126],
#          [ 72,  82, 126],
#          [ 71,  82, 127],
#          ...,
#          [119, 147, 101],
#          [119, 147, 101],
#          [119, 147, 101]],
#
#         [[ 71,  82, 126],
#          [ 71,  82, 127],
#          [ 71,  81, 128],
#          ...,
#          [119, 147, 101],
#          [119, 147, 101],
#          [119, 147, 101]]], dtype=uint8), array([[[ 98, 118,  95],
#          [ 94, 114,  92],
#          [ 88, 107,  88],
#          ...,
#          [ 36,  40,  58],
#          [ 36,  40,  58],
#          [ 36,  40,  58]],
#
#         [[ 95, 114,  94],
#          [ 91, 110,  91],
#          [ 86, 104,  88],
#          ...,
#          [ 36,  40,  58],
#          [ 36,  40,  58],
#          [ 35,  39,  57]],
#
#         [[ 91, 110,  91],
#          [ 88, 106,  90],
#          [ 83, 100,  87],
#          ...,
#          [ 35,  39,  57],
#          [ 35,  39,  57],
#          [ 34,  38,  57]],
#
#         ...,
#
#         [[139, 167, 117],
#          [138, 167, 119],
#          [138, 166, 124],
#          ...,
#          [119, 146, 102],
#          [119, 146, 102],
#          [119, 146, 102]],
#
#         [[138, 167, 119],
#          [138, 166, 122],
#          [138, 165, 127],
#          ...,
#          [119, 146, 102],
#          [119, 146, 102],
#          [119, 146, 102]],
#
#         [[139, 166, 122],
#          [139, 165, 125],
#          [139, 164, 130],
#          ...,
#          [119, 146, 102],
#          [119, 146, 102],
#          [119, 146, 102]]], dtype=uint8), array([[[ 36,  41,  56],
#          [ 36,  41,  57],
#          [ 36,  40,  58],
#          ...,
#          [ 56,  62,  67],
#          [ 58,  64,  68],
#          [ 59,  66,  69]],
#
#         [[ 36,  40,  57],
#          [ 36,  40,  58],
#          [ 37,  40,  59],
#          ...,
#          [ 56,  62,  68],
#          [ 58,  64,  69],
#          [ 60,  66,  70]],
#
#         [[ 36,  40,  59],
#          [ 37,  40,  59],
#          [ 37,  41,  60],
#          ...,
#          [ 57,  63,  70],
#          [ 60,  65,  71],
#          [ 62,  67,  72]],
#
#         ...,
#
#         [[141, 169, 109],
#          [141, 169, 109],
#          [142, 170, 109],
#          ...,
#          [121, 147, 101],
#          [121, 147, 101],
#          [121, 147, 101]],
#
#         [[141, 169, 109],
#          [141, 169, 110],
#          [142, 170, 110],
#          ...,
#          [121, 147, 101],
#          [121, 147, 101],
#          [121, 147, 101]],
#
#         [[141, 169, 110],
#          [141, 169, 110],
#          [142, 170, 111],
#          ...,
#          [122, 148, 102],
#          [121, 147, 101],
#          [121, 147, 101]]], dtype=uint8), array([[[ 59,  70,  67],
#          [ 58,  69,  66],
#          [ 56,  67,  65],
#          ...,
#          [129, 157, 113],
#          [132, 161, 115],
#          [134, 163, 117]],
#
#         [[ 56,  67,  64],
#          [ 54,  65,  64],
#          [ 53,  63,  64],
#          ...,
#          [128, 156, 113],
#          [131, 159, 115],
#          [132, 162, 116]],
#
#         [[ 53,  63,  63],
#          [ 52,  61,  63],
#          [ 51,  60,  63],
#          ...,
#          [126, 153, 112],
#          [128, 156, 113],
#          [130, 158, 114]],
#
#         ...,
#
#         [[144, 168, 114],
#          [144, 168, 114],
#          [144, 168, 114],
#          ...,
#          [119, 148, 102],
#          [119, 148, 102],
#          [119, 148, 102]],
#
#         [[143, 168, 114],
#          [143, 168, 114],
#          [143, 168, 114],
#          ...,
#          [119, 148, 102],
#          [119, 147, 101],
#          [119, 147, 101]],
#
#         [[142, 168, 114],
#          [142, 168, 113],
#          [142, 169, 113],
#          ...,
#          [118, 147, 101],
#          [118, 147, 101],
#          [118, 147, 101]]], dtype=uint8), array([[[ 34,  41,  56],
#          [ 34,  41,  57],
#          [ 34,  41,  58],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[ 35,  42,  59],
#          [ 35,  42,  59],
#          [ 35,  42,  59],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         [[ 37,  43,  61],
#          [ 37,  43,  61],
#          [ 36,  43,  61],
#          ...,
#          [140, 173, 116],
#          [140, 173, 116],
#          [140, 173, 116]],
#
#         ...,
#
#         [[142, 170, 111],
#          [143, 169, 111],
#          [144, 169, 111],
#          ...,
#          [126, 152, 106],
#          [126, 152, 106],
#          [126, 152, 106]],
#
#         [[142, 170, 111],
#          [143, 169, 111],
#          [144, 169, 111],
#          ...,
#          [125, 151, 105],
#          [125, 151, 106],
#          [125, 151, 106]],
#
#         [[142, 170, 111],
#          [143, 169, 111],
#          [144, 169, 111],
#          ...,
#          [125, 151, 105],
#          [125, 151, 105],
#          [125, 151, 105]]], dtype=uint8), array([[[ 39,  52,  54],
#          [ 39,  51,  54],
#          [ 38,  50,  55],
#          ...,
#          [142, 174, 115],
#          [142, 174, 115],
#          [142, 174, 115]],
#
#         [[ 37,  50,  55],
#          [ 37,  49,  55],
#          [ 36,  46,  55],
#          ...,
#          [142, 174, 115],
#          [142, 174, 115],
#          [142, 174, 115]],
#
#         [[ 36,  47,  55],
#          [ 35,  46,  55],
#          [ 34,  44,  55],
#          ...,
#          [142, 174, 115],
#          [142, 174, 115],
#          [142, 174, 115]],
#
#         ...,
#
#         [[143, 170, 114],
#          [143, 170, 114],
#          [143, 170, 114],
#          ...,
#          [126, 155, 106],
#          [126, 155, 106],
#          [126, 155, 106]],
#
#         [[143, 170, 114],
#          [143, 170, 114],
#          [143, 170, 114],
#          ...,
#          [126, 155, 106],
#          [126, 155, 106],
#          [126, 155, 106]],
#
#         [[143, 170, 114],
#          [143, 170, 114],
#          [143, 170, 114],
#          ...,
#          [126, 155, 106],
#          [126, 155, 106],
#          [126, 155, 106]]], dtype=uint8)]

# %%
face_extractor(os.path.join(base_fake,'FakeFrames'),os.path.join(base_fake,'Deepfake'))
# Out:
#  ******    Welcome to Face Extractor     ******
#
#     Progress:
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# Face from image 1 extracted and saved!
# Face from image 2 extracted and saved!
# Face from image 3 extracted and saved!
# Face from image 4 extracted and saved!
# Face from image 5 extracted and saved!
# Face from image 6 extracted and saved!
# Face from image 7 extracted and saved!
# Face from image 8 extracted and saved!
# Face from image 9 extracted and saved!
# Face from image 10 extracted and saved!
# Face from image 11 extracted and saved!
# Face from image 12 extracted and saved!
# Face from image 13 extracted and saved!
# Face from image 14 extracted and saved!
# Face from image 15 extracted and saved!
# Face from image 16 extracted and saved!
# Face from image 17 extracted and saved!
# Face from image 18 extracted and saved!
# Face from image 19 extracted and saved!
# Face from image 20 extracted and saved!
# Face from image 21 extracted and saved!
# Face from image 22 extracted and saved!
# Face from image 23 extracted and saved!
# Face from image 24 extracted and saved!
# Face from image 25 extracted and saved!
# Face from image 26 extracted and saved!
# Face from image 27 extracted and saved!
# Face from image 28 extracted and saved!
# Face from image 29 extracted and saved!
# Face from image 30 extracted and saved!
# Face from image 31 extracted and saved!
# Face from image 32 extracted and saved!
# Face from image 33 extracted and saved!
# Face from image 34 extracted and saved!
# Face from image 35 extracted and saved!
# Face from image 36 extracted and saved!
# Face from image 37 extracted and saved!
# Face from image 38 extracted and saved!
# Face from image 39 extracted and saved!
# Face from image 40 extracted and saved!
# Face from image 41 extracted and saved!
# Face from image 42 extracted and saved!
# Face from image 43 extracted and saved!
# Face from image 44 extracted and saved!
# Face from image 45 extracted and saved!
# Face from image 46 extracted and saved!
# Face from image 47 extracted and saved!
# Face from image 48 extracted and saved!
# Face from image 49 extracted and saved!
# Face from image 50 extracted and saved!
# Face from image 51 extracted and saved!
# Face from image 52 extracted and saved!
# Face from image 53 extracted and saved!
# Face from image 54 extracted and saved!
# Face from image 55 extracted and saved!
# Face from image 56 extracted and saved!
# Face from image 57 extracted and saved!
# Face from image 58 extracted and saved!
# Face from image 59 extracted and saved!
# Face from image 60 extracted and saved!
# Face from image 61 extracted and saved!
# Face from image 62 extracted and saved!
# Face from image 63 extracted and saved!
# Face from image 64 extracted and saved!
# Face from image 65 extracted and saved!
# Face from image 66 extracted and saved!
# Face from image 67 extracted and saved!
# Face from image 68 extracted and saved!
# Face from image 69 extracted and saved!
# Face from image 70 extracted and saved!
# Face from image 71 extracted and saved!
# Face from image 72 extracted and saved!
# Face from image 73 extracted and saved!
# Face from image 74 extracted and saved!
# Face from image 75 extracted and saved!
# Face from image 76 extracted and saved!
# Face from image 77 extracted and saved!
# Face from image 78 extracted and saved!
# Face from image 79 extracted and saved!
# Face from image 80 extracted and saved!
# Face from image 81 extracted and saved!
# Face from image 82 extracted and saved!
# Face from image 83 extracted and saved!
# Face from image 84 extracted and saved!
# Face from image 85 extracted and saved!
# Face from image 86 extracted and saved!
# Face from image 87 extracted and saved!
# Face from image 88 extracted and saved!
# Face from image 89 extracted and saved!
# Face from image 90 extracted and saved!
# Face from image 91 extracted and saved!
# Face from image 92 extracted and saved!
# Face from image 93 extracted and saved!
# Face from image 94 extracted and saved!
# Face from image 95 extracted and saved!
# Face from image 96 extracted and saved!
# Face from image 97 extracted and saved!
# Face from image 98 extracted and saved!
# Face from image 99 extracted and saved!
# Face from image 100 extracted and saved!
# Face from image 101 extracted and saved!
# Face from image 102 extracted and saved!
# Face from image 103 extracted and saved!
# Face from image 104 extracted and saved!
# Face from image 105 extracted and saved!
# Face from image 106 extracted and saved!
# Face from image 107 extracted and saved!
# Face from image 108 extracted and saved!
# Face from image 109 extracted and saved!
# Face from image 110 extracted and saved!
# Face from image 111 extracted and saved!
# Face from image 112 extracted and saved!
# Face from image 113 extracted and saved!
# Face from image 114 extracted and saved!
# Face from image 115 extracted and saved!
# Face from image 116 extracted and saved!
# Face from image 117 extracted and saved!
# Face from image 118 extracted and saved!
# Face from image 119 extracted and saved!
# Face from image 120 extracted and saved!
# Face from image 121 extracted and saved!
# Face from image 122 extracted and saved!
# Face from image 123 extracted and saved!
# Face from image 124 extracted and saved!
# Face from image 125 extracted and saved!
# Face from image 126 extracted and saved!
# Face from image 127 extracted and saved!
# Face from image 128 extracted and saved!
# Face from image 129 extracted and saved!
# Face from image 130 extracted and saved!
# Face from image 131 extracted and saved!
# Face from image 132 extracted and saved!
# Face from image 133 extracted and saved!
# Face from image 134 extracted and saved!
# Face from image 135 extracted and saved!
# Face from image 136 extracted and saved!
# Face from image 137 extracted and saved!
# Face from image 138 extracted and saved!
# Face from image 139 extracted and saved!
# Face from image 140 extracted and saved!
# Face from image 141 extracted and saved!
# Face from image 142 extracted and saved!
# Face from image 143 extracted and saved!
# Face from image 144 extracted and saved!
# Face from image 145 extracted and saved!
# Face from image 146 extracted and saved!
# Face from image 147 extracted and saved!
# Face from image 148 extracted and saved!
# Face from image 149 extracted and saved!
# Face from image 150 extracted and saved!
# Face from image 151 extracted and saved!
# Face from image 152 extracted and saved!
# Face from image 153 extracted and saved!
# Face from image 154 extracted and saved!
# Face from image 155 extracted and saved!
# Face from image 156 extracted and saved!
# Face from image 157 extracted and saved!
# Face from image 158 extracted and saved!
# Face from image 159 extracted and saved!
# Face from image 160 extracted and saved!
# Face from image 161 extracted and saved!
# Face from image 162 extracted and saved!
# Face from image 163 extracted and saved!
# Face from image 164 extracted and saved!
# Face from image 165 extracted and saved!
# Face from image 166 extracted and saved!
# Face from image 167 extracted and saved!
# Face from image 168 extracted and saved!
# Face from image 169 extracted and saved!
# Face from image 170 extracted and saved!
# Face from image 171 extracted and saved!
# Face from image 172 extracted and saved!
# Face from image 173 extracted and saved!
# Face from image 174 extracted and saved!
# Face from image 175 extracted and saved!
# Face from image 176 extracted and saved!
# Face from image 177 extracted and saved!
# Face from image 178 extracted and saved!
# Face from image 179 extracted and saved!
# Face from image 180 extracted and saved!
# Face from image 181 extracted and saved!
# Face from image 182 extracted and saved!
# Face from image 183 extracted and saved!
# Face from image 184 extracted and saved!
# Face from image 185 extracted and saved!
# Face from image 186 extracted and saved!
# Face from image 187 extracted and saved!
# Face from image 188 extracted and saved!
# Face from image 189 extracted and saved!
# Face from image 190 extracted and saved!
# Face from image 191 extracted and saved!
# Face from image 192 extracted and saved!
# Face from image 193 extracted and saved!
# Face from image 194 extracted and saved!
# Face from image 195 extracted and saved!
# Face from image 196 extracted and saved!
# Face from image 197 extracted and saved!
# Face from image 198 extracted and saved!
# Face from image 199 extracted and saved!
# Face from image 200 extracted and saved!
# Face from image 201 extracted and saved!
# Face from image 202 extracted and saved!
# Face from image 203 extracted and saved!
# Face from image 204 extracted and saved!
# Face from image 205 extracted and saved!
# Face from image 206 extracted and saved!
# Face from image 207 extracted and saved!
# Face from image 208 extracted and saved!
# Face from image 209 extracted and saved!
# Face from image 210 extracted and saved!
# Face from image 211 extracted and saved!
# Face from image 212 extracted and saved!
# Face from image 213 extracted and saved!
# Face from image 214 extracted and saved!
# Face from image 215 extracted and saved!
# Face from image 216 extracted and saved!
# Face from image 217 extracted and saved!
# Face from image 218 extracted and saved!
# Face from image 219 extracted and saved!
# Face from image 220 extracted and saved!
# Face from image 221 extracted and saved!
# Face from image 222 extracted and saved!
# Face from image 223 extracted and saved!
# Face from image 224 extracted and saved!
# Face from image 225 extracted and saved!
# Face from image 226 extracted and saved!
# Face from image 227 extracted and saved!
# Face from image 228 extracted and saved!
# Face from image 229 extracted and saved!
# Face from image 230 extracted and saved!
# Face from image 231 extracted and saved!
# Face from image 232 extracted and saved!
# Face from image 233 extracted and saved!
# Face from image 234 extracted and saved!
# Face from image 235 extracted and saved!
# Face from image 236 extracted and saved!
# Face from image 237 extracted and saved!
# Face from image 238 extracted and saved!
# Face from image 239 extracted and saved!
# Face from image 240 extracted and saved!
# Face from image 241 extracted and saved!
# Face from image 242 extracted and saved!
# Face from image 243 extracted and saved!
# Face from image 244 extracted and saved!
# Face from image 245 extracted and saved!
# Face from image 246 extracted and saved!
# Face from image 247 extracted and saved!
# Face from image 248 extracted and saved!
# Face from image 249 extracted and saved!
# Face from image 250 extracted and saved!
# Face from image 251 extracted and saved!
# Face from image 252 extracted and saved!
# Face from image 253 extracted and saved!
# Face from image 254 extracted and saved!
# Face from image 255 extracted and saved!
# Face from image 256 extracted and saved!
# Face from image 257 extracted and saved!
# Face from image 258 extracted and saved!
# Face from image 259 extracted and saved!
# Face from image 260 extracted and saved!
# Face from image 261 extracted and saved!
# Face from image 262 extracted and saved!
# Face from image 263 extracted and saved!
# Face from image 264 extracted and saved!
# Face from image 265 extracted and saved!
# Face from image 266 extracted and saved!
# Face from image 267 extracted and saved!
# Face from image 268 extracted and saved!
# Face from image 269 extracted and saved!
# Face from image 270 extracted and saved!
# Face from image 271 extracted and saved!
# Face from image 272 extracted and saved!
# Face from image 273 extracted and saved!
# Face from image 274 extracted and saved!
# Face from image 275 extracted and saved!
# Face from image 276 extracted and saved!
# Face from image 277 extracted and saved!
# Face from image 278 extracted and saved!
# Face from image 279 extracted and saved!
# Face from image 280 extracted and saved!
# Face from image 281 extracted and saved!
# Face from image 282 extracted and saved!
# Face from image 283 extracted and saved!
# Face from image 284 extracted and saved!
# Face from image 285 extracted and saved!
# Face from image 286 extracted and saved!
# Face from image 287 extracted and saved!
# Face from image 288 extracted and saved!
# Face from image 289 extracted and saved!
# Face from image 290 extracted and saved!
# Face from image 291 extracted and saved!
# Face from image 292 extracted and saved!
# Face from image 293 extracted and saved!
# Face from image 294 extracted and saved!
# Face from image 295 extracted and saved!
# Face from image 296 extracted and saved!
# Face from image 297 extracted and saved!
# Face from image 298 extracted and saved!
# Face from image 299 extracted and saved!
# Face from image 300 extracted and saved!
# [array([[[115, 127, 137],
#          [107, 121, 131],
#          [100, 115, 124],
#          ...,
#          [ 59,  64,  77],
#          [ 63,  70,  83],
#          [ 67,  75,  88]],
#
#         [[110, 122, 132],
#          [104, 118, 128],
#          [100, 115, 124],
#          ...,
#          [ 51,  56,  70],
#          [ 56,  62,  76],
#          [ 59,  68,  81]],
#
#         [[101, 113, 123],
#          [ 98, 112, 122],
#          [ 97, 112, 121],
#          ...,
#          [ 46,  51,  64],
#          [ 49,  55,  68],
#          [ 51,  59,  72]],
#
#         ...,
#
#         [[ 15,  18,  16],
#          [ 14,  17,  15],
#          [ 14,  17,  15],
#          ...,
#          [139, 176, 198],
#          [142, 180, 202],
#          [143, 182, 204]],
#
#         [[ 13,  18,  16],
#          [ 13,  17,  15],
#          [ 14,  17,  15],
#          ...,
#          [142, 179, 201],
#          [144, 182, 204],
#          [145, 184, 206]],
#
#         [[ 12,  17,  15],
#          [ 13,  17,  15],
#          [ 14,  17,  15],
#          ...,
#          [144, 181, 203],
#          [146, 184, 206],
#          [146, 185, 207]]], dtype=uint8), array([[[115, 127, 137],
#          [107, 121, 131],
#          [100, 115, 124],
#          ...,
#          [ 59,  63,  77],
#          [ 63,  70,  83],
#          [ 67,  75,  88]],
#
#         [[110, 122, 132],
#          [105, 118, 128],
#          [100, 115, 124],
#          ...,
#          [ 51,  56,  69],
#          [ 56,  63,  76],
#          [ 60,  68,  81]],
#
#         [[101, 113, 123],
#          [ 98, 112, 122],
#          [ 97, 112, 121],
#          ...,
#          [ 46,  51,  64],
#          [ 48,  55,  68],
#          [ 51,  59,  72]],
#
#         ...,
#
#         [[ 13,  18,  16],
#          [ 14,  17,  15],
#          [ 14,  17,  15],
#          ...,
#          [142, 179, 201],
#          [145, 182, 204],
#          [145, 184, 206]],
#
#         [[ 12,  17,  15],
#          [ 13,  17,  15],
#          [ 14,  17,  15],
#          ...,
#          [144, 181, 203],
#          [146, 184, 206],
#          [146, 185, 207]],
#
#         [[ 13,  18,  16],
#          [ 13,  18,  16],
#          [ 13,  18,  16],
#          ...,
#          [145, 182, 204],
#          [146, 184, 206],
#          [146, 185, 207]]], dtype=uint8), array([[[ 96, 111, 120],
#          [105, 121, 130],
#          [114, 130, 139],
#          ...,
#          [ 45,  49,  59],
#          [ 45,  49,  60],
#          [ 45,  49,  60]],
#
#         [[107, 124, 132],
#          [111, 129, 137],
#          [115, 132, 141],
#          ...,
#          [ 46,  50,  60],
#          [ 46,  50,  61],
#          [ 47,  51,  62]],
#
#         [[116, 133, 142],
#          [116, 133, 142],
#          [114, 131, 140],
#          ...,
#          [ 46,  51,  61],
#          [ 47,  51,  62],
#          [ 48,  52,  63]],
#
#         ...,
#
#         [[ 23,  31,  30],
#          [ 23,  30,  29],
#          [ 23,  29,  28],
#          ...,
#          [141, 175, 199],
#          [140, 175, 199],
#          [139, 175, 199]],
#
#         [[ 23,  31,  30],
#          [ 23,  29,  29],
#          [ 23,  29,  28],
#          ...,
#          [141, 175, 199],
#          [140, 174, 198],
#          [139, 175, 199]],
#
#         [[ 22,  30,  30],
#          [ 21,  29,  29],
#          [ 20,  28,  28],
#          ...,
#          [141, 175, 199],
#          [141, 176, 200],
#          [141, 177, 201]]], dtype=uint8), array([[[ 90, 105, 114],
#          [ 89, 104, 113],
#          [ 86, 101, 110],
#          ...,
#          [ 39,  45,  52],
#          [ 39,  45,  52],
#          [ 39,  45,  52]],
#
#         [[ 87, 102, 111],
#          [ 85, 100, 109],
#          [ 83,  98, 107],
#          ...,
#          [ 40,  46,  53],
#          [ 39,  45,  52],
#          [ 39,  45,  52]],
#
#         [[ 83,  99, 109],
#          [ 81,  98, 107],
#          [ 79,  95, 104],
#          ...,
#          [ 41,  47,  54],
#          [ 41,  47,  54],
#          [ 41,  46,  54]],
#
#         ...,
#
#         [[ 16,  18,  19],
#          [ 16,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [136, 171, 197],
#          [137, 172, 198],
#          [140, 175, 201]],
#
#         [[ 16,  18,  19],
#          [ 16,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [138, 173, 199],
#          [138, 173, 199],
#          [140, 175, 201]],
#
#         [[ 16,  18,  19],
#          [ 16,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [139, 174, 200],
#          [138, 173, 199],
#          [139, 174, 200]]], dtype=uint8), array([[[ 63,  78,  87],
#          [ 58,  73,  82],
#          [ 54,  69,  78],
#          ...,
#          [ 50,  53,  65],
#          [ 50,  54,  65],
#          [ 51,  55,  66]],
#
#         [[ 59,  74,  83],
#          [ 57,  72,  81],
#          [ 54,  69,  78],
#          ...,
#          [ 50,  54,  65],
#          [ 51,  55,  66],
#          [ 51,  55,  66]],
#
#         [[ 56,  71,  80],
#          [ 55,  70,  79],
#          [ 54,  69,  78],
#          ...,
#          [ 50,  54,  65],
#          [ 51,  55,  66],
#          [ 52,  56,  67]],
#
#         ...,
#
#         [[ 17,  18,  22],
#          [ 16,  18,  20],
#          [ 15,  17,  19],
#          ...,
#          [158, 200, 219],
#          [158, 200, 219],
#          [158, 200, 219]],
#
#         [[ 16,  17,  21],
#          [ 15,  17,  19],
#          [ 15,  16,  18],
#          ...,
#          [159, 201, 220],
#          [159, 201, 220],
#          [159, 201, 220]],
#
#         [[ 16,  17,  21],
#          [ 15,  17,  19],
#          [ 14,  16,  18],
#          ...,
#          [160, 202, 222],
#          [160, 202, 221],
#          [161, 203, 222]]], dtype=uint8), array([[[114, 129, 138],
#          [110, 124, 134],
#          [105, 120, 129],
#          ...,
#          [ 38,  44,  49],
#          [ 38,  44,  49],
#          [ 39,  45,  50]],
#
#         [[111, 126, 135],
#          [106, 121, 130],
#          [100, 115, 124],
#          ...,
#          [ 38,  44,  49],
#          [ 38,  44,  49],
#          [ 38,  44,  49]],
#
#         [[107, 122, 131],
#          [101, 117, 125],
#          [ 95, 110, 119],
#          ...,
#          [ 37,  43,  50],
#          [ 37,  43,  50],
#          [ 38,  44,  51]],
#
#         ...,
#
#         [[ 15,  15,  21],
#          [ 15,  15,  22],
#          [ 16,  16,  22],
#          ...,
#          [158, 199, 222],
#          [158, 199, 222],
#          [159, 200, 223]],
#
#         [[ 15,  15,  21],
#          [ 16,  16,  22],
#          [ 16,  17,  22],
#          ...,
#          [158, 199, 221],
#          [159, 200, 222],
#          [160, 201, 223]],
#
#         [[ 15,  15,  21],
#          [ 15,  15,  22],
#          [ 16,  16,  22],
#          ...,
#          [159, 200, 222],
#          [160, 201, 222],
#          [161, 203, 222]]], dtype=uint8), array([[[ 68,  80,  90],
#          [ 77,  89,  99],
#          [ 88, 101, 110],
#          ...,
#          [ 27,  36,  39],
#          [ 28,  37,  40],
#          [ 29,  38,  41]],
#
#         [[ 76,  88,  98],
#          [ 87,  99, 109],
#          [ 99, 112, 121],
#          ...,
#          [ 28,  36,  40],
#          [ 29,  37,  40],
#          [ 31,  38,  41]],
#
#         [[ 91, 106, 115],
#          [101, 116, 125],
#          [109, 124, 133],
#          ...,
#          [ 28,  33,  39],
#          [ 30,  35,  40],
#          [ 33,  37,  42]],
#
#         ...,
#
#         [[ 15,  15,  21],
#          [ 15,  16,  20],
#          [ 15,  16,  20],
#          ...,
#          [138, 171, 197],
#          [140, 172, 199],
#          [142, 174, 203]],
#
#         [[ 14,  14,  20],
#          [ 15,  15,  20],
#          [ 15,  16,  20],
#          ...,
#          [141, 174, 201],
#          [141, 174, 201],
#          [142, 174, 203]],
#
#         [[ 14,  14,  20],
#          [ 15,  15,  20],
#          [ 15,  15,  21],
#          ...,
#          [145, 178, 204],
#          [143, 176, 202],
#          [141, 176, 202]]], dtype=uint8), array([[[ 78,  93, 102],
#          [ 83,  98, 107],
#          [ 92, 107, 116],
#          ...,
#          [ 24,  31,  33],
#          [ 23,  31,  33],
#          [ 22,  32,  32]],
#
#         [[ 89, 105, 114],
#          [ 95, 111, 120],
#          [103, 118, 127],
#          ...,
#          [ 24,  31,  33],
#          [ 24,  31,  34],
#          [ 23,  32,  35]],
#
#         [[ 97, 112, 121],
#          [104, 119, 128],
#          [112, 127, 136],
#          ...,
#          [ 24,  31,  35],
#          [ 25,  32,  35],
#          [ 24,  33,  36]],
#
#         ...,
#
#         [[ 18,  17,  19],
#          [ 17,  17,  19],
#          [ 16,  17,  18],
#          ...,
#          [128, 156, 180],
#          [127, 156, 180],
#          [127, 158, 181]],
#
#         [[ 17,  16,  18],
#          [ 16,  17,  19],
#          [ 15,  17,  19],
#          ...,
#          [130, 158, 182],
#          [129, 158, 182],
#          [129, 160, 183]],
#
#         [[ 18,  17,  19],
#          [ 17,  17,  19],
#          [ 16,  17,  18],
#          ...,
#          [131, 160, 185],
#          [131, 161, 186],
#          [133, 164, 187]]], dtype=uint8), array([[[ 75,  91,  98],
#          [ 82,  97, 106],
#          [ 92, 107, 116],
#          ...,
#          [ 23,  31,  34],
#          [ 24,  33,  36],
#          [ 25,  34,  37]],
#
#         [[ 79,  95, 102],
#          [ 82,  98, 106],
#          [ 91, 106, 115],
#          ...,
#          [ 23,  31,  34],
#          [ 24,  33,  36],
#          [ 25,  34,  37]],
#
#         [[ 85, 101, 108],
#          [ 88, 103, 111],
#          [ 97, 112, 121],
#          ...,
#          [ 23,  31,  34],
#          [ 24,  33,  36],
#          [ 25,  34,  37]],
#
#         ...,
#
#         [[ 14,  18,  19],
#          [ 13,  18,  18],
#          [ 13,  18,  17],
#          ...,
#          [154, 184, 210],
#          [155, 186, 211],
#          [156, 187, 212]],
#
#         [[ 14,  18,  19],
#          [ 13,  18,  18],
#          [ 13,  18,  17],
#          ...,
#          [155, 186, 211],
#          [156, 188, 212],
#          [155, 189, 213]],
#
#         [[ 15,  17,  18],
#          [ 14,  18,  18],
#          [ 14,  19,  18],
#          ...,
#          [156, 187, 212],
#          [156, 189, 213],
#          [156, 190, 214]]], dtype=uint8), array([[[118, 134, 141],
#          [119, 135, 143],
#          [120, 135, 144],
#          ...,
#          [ 20,  24,  25],
#          [ 20,  24,  25],
#          [ 21,  25,  26]],
#
#         [[122, 138, 145],
#          [124, 138, 147],
#          [124, 136, 146],
#          ...,
#          [ 21,  25,  26],
#          [ 21,  24,  27],
#          [ 21,  24,  28]],
#
#         [[119, 135, 142],
#          [122, 135, 144],
#          [122, 134, 144],
#          ...,
#          [ 22,  26,  27],
#          [ 21,  25,  27],
#          [ 21,  24,  28]],
#
#         ...,
#
#         [[ 16,  18,  19],
#          [ 16,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [143, 173, 200],
#          [145, 177, 203],
#          [147, 180, 206]],
#
#         [[ 16,  18,  19],
#          [ 16,  18,  19],
#          [ 16,  18,  18],
#          ...,
#          [145, 177, 203],
#          [148, 181, 207],
#          [150, 183, 209]],
#
#         [[ 17,  19,  20],
#          [ 16,  18,  19],
#          [ 15,  18,  19],
#          ...,
#          [147, 180, 206],
#          [150, 183, 209],
#          [152, 185, 211]]], dtype=uint8), array([[[ 85, 101, 108],
#          [ 83,  99, 106],
#          [ 86, 101, 109],
#          ...,
#          [ 19,  22,  24],
#          [ 19,  23,  24],
#          [ 19,  23,  24]],
#
#         [[ 87, 102, 111],
#          [ 90, 105, 114],
#          [ 96, 111, 120],
#          ...,
#          [ 18,  23,  25],
#          [ 19,  23,  24],
#          [ 20,  24,  25]],
#
#         [[ 87, 102, 111],
#          [ 94, 109, 118],
#          [103, 118, 127],
#          ...,
#          [ 18,  22,  24],
#          [ 18,  22,  23],
#          [ 19,  23,  24]],
#
#         ...,
#
#         [[ 16,  18,  18],
#          [ 16,  18,  18],
#          [ 16,  18,  18],
#          ...,
#          [152, 185, 211],
#          [153, 187, 213],
#          [153, 188, 214]],
#
#         [[ 15,  20,  19],
#          [ 15,  19,  18],
#          [ 16,  18,  18],
#          ...,
#          [152, 186, 212],
#          [154, 188, 214],
#          [155, 190, 216]],
#
#         [[ 13,  18,  19],
#          [ 14,  18,  18],
#          [ 14,  19,  18],
#          ...,
#          [153, 188, 214],
#          [154, 189, 215],
#          [155, 190, 216]]], dtype=uint8), array([[[ 72,  87,  96],
#          [ 82,  97, 106],
#          [ 93, 108, 117],
#          ...,
#          [ 21,  25,  26],
#          [ 23,  27,  28],
#          [ 24,  28,  29]],
#
#         [[ 91, 106, 115],
#          [100, 115, 124],
#          [109, 124, 133],
#          ...,
#          [ 21,  25,  26],
#          [ 22,  26,  27],
#          [ 24,  28,  29]],
#
#         [[101, 116, 125],
#          [108, 123, 132],
#          [114, 129, 138],
#          ...,
#          [ 21,  25,  25],
#          [ 22,  26,  27],
#          [ 23,  27,  28]],
#
#         ...,
#
#         [[ 15,  19,  20],
#          [ 15,  19,  20],
#          [ 14,  18,  19],
#          ...,
#          [154, 188, 214],
#          [154, 190, 215],
#          [155, 190, 216]],
#
#         [[ 15,  19,  20],
#          [ 14,  18,  19],
#          [ 13,  18,  18],
#          ...,
#          [155, 190, 216],
#          [156, 191, 217],
#          [157, 192, 218]],
#
#         [[ 13,  18,  19],
#          [ 13,  18,  19],
#          [ 13,  17,  18],
#          ...,
#          [155, 190, 216],
#          [155, 191, 217],
#          [155, 192, 218]]], dtype=uint8), array([[[ 73,  86,  94],
#          [ 76,  89,  97],
#          [ 80,  94, 102],
#          ...,
#          [ 19,  23,  24],
#          [ 21,  25,  26],
#          [ 22,  26,  27]],
#
#         [[ 73,  89,  96],
#          [ 76,  91,  99],
#          [ 82,  98, 105],
#          ...,
#          [ 18,  22,  23],
#          [ 19,  23,  24],
#          [ 20,  24,  25]],
#
#         [[ 78,  94, 101],
#          [ 82,  97, 105],
#          [ 89, 104, 111],
#          ...,
#          [ 19,  23,  24],
#          [ 20,  24,  25],
#          [ 21,  26,  26]],
#
#         ...,
#
#         [[ 15,  17,  18],
#          [ 15,  17,  18],
#          [ 15,  17,  18],
#          ...,
#          [145, 174, 199],
#          [147, 177, 202],
#          [148, 178, 203]],
#
#         [[ 15,  17,  18],
#          [ 15,  17,  18],
#          [ 15,  17,  18],
#          ...,
#          [148, 178, 203],
#          [151, 181, 206],
#          [151, 182, 207]],
#
#         [[ 15,  17,  18],
#          [ 15,  17,  18],
#          [ 15,  17,  18],
#          ...,
#          [150, 180, 205],
#          [153, 183, 208],
#          [154, 185, 210]]], dtype=uint8), array([[[ 76,  89,  97],
#          [ 71,  85,  94],
#          [ 68,  83,  92],
#          ...,
#          [ 24,  28,  29],
#          [ 26,  29,  31],
#          [ 27,  30,  34]],
#
#         [[ 72,  85,  93],
#          [ 69,  83,  92],
#          [ 68,  83,  92],
#          ...,
#          [ 22,  26,  27],
#          [ 24,  27,  29],
#          [ 24,  27,  31]],
#
#         [[ 70,  83,  91],
#          [ 69,  83,  92],
#          [ 70,  85,  94],
#          ...,
#          [ 22,  25,  29],
#          [ 23,  26,  30],
#          [ 24,  27,  31]],
#
#         ...,
#
#         [[ 14,  18,  19],
#          [ 15,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [156, 190, 216],
#          [155, 191, 217],
#          [154, 191, 217]],
#
#         [[ 14,  18,  19],
#          [ 15,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [154, 190, 216],
#          [153, 191, 216],
#          [152, 192, 217]],
#
#         [[ 14,  18,  19],
#          [ 15,  18,  19],
#          [ 16,  18,  19],
#          ...,
#          [155, 191, 217],
#          [154, 192, 218],
#          [154, 194, 219]]], dtype=uint8), array([[[ 67,  83,  90],
#          [ 67,  83,  90],
#          [ 68,  84,  91],
#          ...,
#          [ 20,  23,  24],
#          [ 21,  25,  26],
#          [ 22,  26,  27]],
#
#         [[ 65,  81,  88],
#          [ 66,  82,  89],
#          [ 68,  84,  91],
#          ...,
#          [ 20,  24,  25],
#          [ 21,  25,  26],
#          [ 22,  26,  27]],
#
#         [[ 64,  80,  87],
#          [ 66,  82,  89],
#          [ 68,  84,  92],
#          ...,
#          [ 21,  24,  26],
#          [ 22,  26,  27],
#          [ 23,  27,  28]],
#
#         ...,
#
#         [[ 14,  19,  18],
#          [ 13,  18,  17],
#          [ 13,  18,  17],
#          ...,
#          [142, 174, 199],
#          [145, 178, 202],
#          [148, 182, 206]],
#
#         [[ 14,  19,  18],
#          [ 13,  18,  17],
#          [ 13,  18,  17],
#          ...,
#          [143, 175, 200],
#          [145, 179, 204],
#          [149, 183, 207]],
#
#         [[ 14,  19,  18],
#          [ 14,  19,  18],
#          [ 14,  18,  17],
#          ...,
#          [144, 176, 202],
#          [146, 179, 205],
#          [150, 183, 209]]], dtype=uint8), array([[[ 72,  89,  98],
#          [ 77,  94, 103],
#          [ 85, 103, 112],
#          ...,
#          [ 25,  29,  32],
#          [ 26,  31,  34],
#          [ 27,  32,  35]],
#
#         [[ 81,  98, 107],
#          [ 87, 104, 114],
#          [ 96, 114, 123],
#          ...,
#          [ 26,  30,  33],
#          [ 26,  31,  34],
#          [ 27,  32,  35]],
#
#         [[ 90, 107, 116],
#          [ 96, 113, 122],
#          [104, 121, 130],
#          ...,
#          [ 26,  32,  35],
#          [ 27,  32,  35],
#          [ 28,  33,  36]],
#
#         ...,
#
#         [[ 20,  22,  30],
#          [ 20,  22,  30],
#          [ 20,  22,  31],
#          ...,
#          [161, 207, 229],
#          [161, 209, 228],
#          [162, 210, 228]],
#
#         [[ 20,  22,  30],
#          [ 21,  23,  30],
#          [ 21,  23,  32],
#          ...,
#          [160, 207, 229],
#          [161, 208, 228],
#          [161, 209, 227]],
#
#         [[ 21,  23,  31],
#          [ 21,  22,  31],
#          [ 21,  23,  33],
#          ...,
#          [161, 208, 229],
#          [161, 208, 228],
#          [161, 209, 227]]], dtype=uint8), array([[[ 88, 101, 109],
#          [ 87, 102, 109],
#          [ 84,  99, 107],
#          ...,
#          [ 25,  29,  30],
#          [ 27,  31,  32],
#          [ 28,  32,  33]],
#
#         [[ 90, 103, 111],
#          [ 85, 100, 107],
#          [ 79,  95, 102],
#          ...,
#          [ 24,  28,  29],
#          [ 25,  29,  30],
#          [ 26,  30,  31]],
#
#         [[ 88, 101, 109],
#          [ 81,  96, 103],
#          [ 73,  89,  95],
#          ...,
#          [ 22,  26,  29],
#          [ 23,  27,  30],
#          [ 23,  28,  31]],
#
#         ...,
#
#         [[ 19,  21,  22],
#          [ 19,  21,  22],
#          [ 18,  20,  21],
#          ...,
#          [151, 185, 214],
#          [153, 187, 216],
#          [155, 189, 218]],
#
#         [[ 19,  21,  22],
#          [ 19,  21,  22],
#          [ 18,  21,  21],
#          ...,
#          [151, 187, 215],
#          [153, 190, 218],
#          [155, 192, 220]],
#
#         [[ 20,  22,  23],
#          [ 20,  22,  23],
#          [ 19,  22,  22],
#          ...,
#          [153, 189, 217],
#          [155, 192, 220],
#          [157, 194, 222]]], dtype=uint8), array([[[ 86,  99, 107],
#          [ 85,  98, 106],
#          [ 85,  98, 106],
#          ...,
#          [ 36,  41,  42],
#          [ 39,  43,  44],
#          [ 41,  45,  46]],
#
#         [[ 88, 101, 109],
#          [ 87, 100, 108],
#          [ 87, 100, 108],
#          ...,
#          [ 33,  37,  38],
#          [ 35,  39,  40],
#          [ 36,  40,  41]],
#
#         [[ 85,  98, 105],
#          [ 84,  97, 105],
#          [ 84,  96, 105],
#          ...,
#          [ 29,  33,  34],
#          [ 31,  35,  36],
#          [ 32,  36,  36]],
#
#         ...,
#
#         [[ 18,  19,  23],
#          [ 19,  20,  25],
#          [ 19,  20,  26],
#          ...,
#          [131, 162, 187],
#          [133, 164, 189],
#          [135, 167, 192]],
#
#         [[ 20,  21,  25],
#          [ 20,  21,  26],
#          [ 20,  21,  27],
#          ...,
#          [134, 165, 190],
#          [137, 169, 193],
#          [139, 173, 197]],
#
#         [[ 20,  21,  25],
#          [ 21,  21,  26],
#          [ 20,  21,  27],
#          ...,
#          [137, 168, 193],
#          [139, 172, 196],
#          [142, 176, 200]]], dtype=uint8), array([[[ 83,  99, 105],
#          [ 79,  97, 103],
#          [ 76,  95, 100],
#          ...,
#          [ 25,  29,  33],
#          [ 27,  30,  33],
#          [ 28,  32,  33]],
#
#         [[ 77,  96, 101],
#          [ 73,  92,  97],
#          [ 69,  88,  93],
#          ...,
#          [ 27,  28,  32],
#          [ 28,  29,  33],
#          [ 29,  30,  34]],
#
#         [[ 73,  92,  98],
#          [ 67,  87,  91],
#          [ 62,  81,  86],
#          ...,
#          [ 27,  27,  32],
#          [ 27,  28,  32],
#          [ 28,  29,  33]],
#
#         ...,
#
#         [[ 23,  25,  26],
#          [ 22,  24,  27],
#          [ 22,  23,  27],
#          ...,
#          [131, 163, 187],
#          [135, 167, 191],
#          [138, 170, 193]],
#
#         [[ 24,  26,  27],
#          [ 23,  25,  27],
#          [ 23,  23,  27],
#          ...,
#          [133, 166, 190],
#          [136, 170, 194],
#          [139, 173, 196]],
#
#         [[ 25,  27,  28],
#          [ 24,  25,  28],
#          [ 23,  24,  28],
#          ...,
#          [136, 170, 194],
#          [139, 174, 198],
#          [141, 177, 201]]], dtype=uint8), array([[[ 83,  96, 104],
#          [ 80,  93, 101],
#          [ 77,  90,  99],
#          ...,
#          [ 28,  31,  36],
#          [ 27,  30,  35],
#          [ 27,  30,  35]],
#
#         [[ 77,  90,  98],
#          [ 76,  89,  97],
#          [ 75,  87,  96],
#          ...,
#          [ 30,  33,  38],
#          [ 29,  32,  37],
#          [ 28,  31,  36]],
#
#         [[ 69,  84,  92],
#          [ 70,  84,  93],
#          [ 70,  85,  94],
#          ...,
#          [ 30,  33,  38],
#          [ 29,  32,  37],
#          [ 29,  32,  37]],
#
#         ...,
#
#         [[ 17,  20,  25],
#          [ 17,  20,  27],
#          [ 19,  21,  29],
#          ...,
#          [ 96, 118, 145],
#          [100, 122, 147],
#          [103, 125, 150]],
#
#         [[ 17,  19,  27],
#          [ 17,  19,  27],
#          [ 18,  20,  29],
#          ...,
#          [ 95, 118, 144],
#          [ 99, 122, 147],
#          [102, 126, 150]],
#
#         [[ 17,  19,  27],
#          [ 17,  19,  27],
#          [ 18,  20,  29],
#          ...,
#          [ 97, 120, 146],
#          [101, 124, 149],
#          [105, 129, 153]]], dtype=uint8), array([[[ 88,  97, 110],
#          [ 88,  97, 110],
#          [ 87,  97, 110],
#          ...,
#          [ 50,  50,  56],
#          [ 53,  53,  59],
#          [ 56,  56,  62]],
#
#         [[ 89,  98, 108],
#          [ 88,  97, 109],
#          [ 87,  95, 108],
#          ...,
#          [ 48,  49,  53],
#          [ 50,  51,  56],
#          [ 52,  53,  57]],
#
#         [[ 89,  99, 109],
#          [ 88,  97, 107],
#          [ 86,  94, 105],
#          ...,
#          [ 45,  46,  50],
#          [ 46,  47,  51],
#          [ 48,  49,  53]],
#
#         ...,
#
#         [[ 25,  28,  43],
#          [ 30,  34,  50],
#          [ 37,  40,  59],
#          ...,
#          [116, 137, 160],
#          [117, 138, 161],
#          [118, 139, 162]],
#
#         [[ 26,  29,  44],
#          [ 31,  35,  52],
#          [ 38,  42,  60],
#          ...,
#          [115, 137, 162],
#          [116, 138, 163],
#          [116, 138, 163]],
#
#         [[ 26,  29,  44],
#          [ 31,  35,  52],
#          [ 38,  42,  61],
#          ...,
#          [114, 136, 161],
#          [115, 138, 162],
#          [115, 139, 163]]], dtype=uint8), array([[[111, 126, 135],
#          [114, 129, 138],
#          [115, 130, 139],
#          ...,
#          [ 31,  35,  40],
#          [ 31,  35,  40],
#          [ 31,  35,  40]],
#
#         [[113, 128, 137],
#          [114, 129, 138],
#          [114, 129, 138],
#          ...,
#          [ 31,  35,  40],
#          [ 30,  35,  40],
#          [ 30,  34,  39]],
#
#         [[114, 130, 139],
#          [113, 129, 138],
#          [112, 128, 137],
#          ...,
#          [ 30,  34,  38],
#          [ 29,  34,  38],
#          [ 29,  34,  38]],
#
#         ...,
#
#         [[ 74,  80, 109],
#          [ 76,  82, 111],
#          [ 79,  85, 114],
#          ...,
#          [ 70,  82, 100],
#          [ 74,  86, 104],
#          [ 78,  90, 108]],
#
#         [[ 75,  81, 110],
#          [ 77,  83, 112],
#          [ 79,  86, 115],
#          ...,
#          [ 73,  85, 103],
#          [ 78,  90, 108],
#          [ 82,  94, 112]],
#
#         [[ 75,  81, 110],
#          [ 77,  83, 113],
#          [ 79,  85, 116],
#          ...,
#          [ 76,  87, 105],
#          [ 80,  92, 110],
#          [ 85,  97, 115]]], dtype=uint8), array([[[ 90,  99, 112],
#          [ 90, 100, 111],
#          [ 90, 100, 110],
#          ...,
#          [ 39,  42,  47],
#          [ 40,  43,  48],
#          [ 41,  44,  49]],
#
#         [[ 87,  99, 111],
#          [ 87,  99, 110],
#          [ 87,  99, 109],
#          ...,
#          [ 40,  43,  48],
#          [ 41,  44,  48],
#          [ 42,  45,  49]],
#
#         [[ 86,  98, 110],
#          [ 86,  98, 109],
#          [ 85,  97, 107],
#          ...,
#          [ 40,  43,  48],
#          [ 41,  44,  48],
#          [ 42,  45,  49]],
#
#         ...,
#
#         [[ 52,  59,  79],
#          [ 59,  65,  87],
#          [ 64,  70,  94],
#          ...,
#          [114, 135, 157],
#          [116, 137, 159],
#          [118, 139, 161]],
#
#         [[ 53,  60,  80],
#          [ 60,  66,  88],
#          [ 64,  71,  94],
#          ...,
#          [115, 136, 158],
#          [117, 138, 160],
#          [118, 139, 161]],
#
#         [[ 55,  62,  82],
#          [ 61,  68,  90],
#          [ 66,  72,  96],
#          ...,
#          [114, 136, 160],
#          [116, 139, 161],
#          [117, 140, 162]]], dtype=uint8), array([[[ 82,  98, 105],
#          [ 82,  98, 105],
#          [ 82,  98, 105],
#          ...,
#          [ 30,  28,  37],
#          [ 30,  27,  36],
#          [ 30,  27,  36]],
#
#         [[ 85,  97, 107],
#          [ 84,  97, 106],
#          [ 83,  96, 106],
#          ...,
#          [ 29,  29,  35],
#          [ 29,  29,  35],
#          [ 29,  28,  35]],
#
#         [[ 86,  98, 107],
#          [ 85,  97, 107],
#          [ 84,  96, 106],
#          ...,
#          [ 30,  31,  37],
#          [ 30,  30,  36],
#          [ 30,  30,  36]],
#
#         ...,
#
#         [[ 68,  73, 101],
#          [ 70,  76, 104],
#          [ 72,  79, 107],
#          ...,
#          [ 59,  67,  87],
#          [ 59,  68,  88],
#          [ 59,  68,  88]],
#
#         [[ 67,  74, 101],
#          [ 70,  77, 104],
#          [ 72,  80, 107],
#          ...,
#          [ 60,  69,  89],
#          [ 61,  70,  90],
#          [ 61,  70,  90]],
#
#         [[ 68,  75, 102],
#          [ 71,  78, 105],
#          [ 74,  81, 109],
#          ...,
#          [ 61,  70,  90],
#          [ 62,  71,  91],
#          [ 63,  72,  92]]], dtype=uint8), array([[[ 86,  98, 108],
#          [ 83,  97, 107],
#          [ 82,  97, 106],
#          ...,
#          [ 28,  27,  35],
#          [ 28,  27,  36],
#          [ 29,  28,  37]],
#
#         [[ 85,  97, 107],
#          [ 84,  97, 107],
#          [ 83,  98, 107],
#          ...,
#          [ 29,  28,  36],
#          [ 29,  28,  37],
#          [ 29,  28,  37]],
#
#         [[ 85,  97, 107],
#          [ 84,  97, 107],
#          [ 83,  98, 107],
#          ...,
#          [ 30,  30,  38],
#          [ 30,  29,  38],
#          [ 30,  29,  38]],
#
#         ...,
#
#         [[ 72,  80, 109],
#          [ 73,  82, 112],
#          [ 75,  85, 115],
#          ...,
#          [ 60,  69,  88],
#          [ 61,  70,  90],
#          [ 62,  71,  91]],
#
#         [[ 72,  80, 109],
#          [ 73,  82, 112],
#          [ 75,  85, 115],
#          ...,
#          [ 61,  70,  88],
#          [ 61,  71,  89],
#          [ 62,  72,  90]],
#
#         [[ 74,  82, 111],
#          [ 75,  83, 113],
#          [ 76,  86, 116],
#          ...,
#          [ 62,  72,  89],
#          [ 62,  73,  91],
#          [ 62,  74,  92]]], dtype=uint8), array([[[ 89, 101, 111],
#          [ 89, 101, 111],
#          [ 89, 101, 110],
#          ...,
#          [ 29,  30,  38],
#          [ 27,  30,  38],
#          [ 27,  30,  38]],
#
#         [[ 89, 101, 111],
#          [ 88, 100, 110],
#          [ 88, 100, 110],
#          ...,
#          [ 29,  31,  39],
#          [ 27,  31,  39],
#          [ 27,  32,  40]],
#
#         [[ 88, 100, 110],
#          [ 88, 100, 110],
#          [ 87,  99, 109],
#          ...,
#          [ 31,  33,  41],
#          [ 30,  34,  42],
#          [ 29,  35,  42]],
#
#         ...,
#
#         [[ 75,  84, 113],
#          [ 75,  86, 114],
#          [ 77,  88, 117],
#          ...,
#          [ 58,  65,  84],
#          [ 59,  67,  86],
#          [ 58,  68,  87]],
#
#         [[ 74,  85, 113],
#          [ 75,  86, 115],
#          [ 76,  87, 117],
#          ...,
#          [ 59,  66,  85],
#          [ 59,  67,  87],
#          [ 60,  69,  89]],
#
#         [[ 75,  85, 115],
#          [ 76,  87, 117],
#          [ 77,  89, 119],
#          ...,
#          [ 60,  67,  86],
#          [ 60,  68,  87],
#          [ 61,  70,  90]]], dtype=uint8), array([[[ 87, 105, 112],
#          [ 89, 106, 112],
#          [ 90, 106, 113],
#          ...,
#          [ 36,  41,  42],
#          [ 38,  43,  44],
#          [ 39,  44,  45]],
#
#         [[ 84, 102, 109],
#          [ 85, 102, 109],
#          [ 86, 102, 109],
#          ...,
#          [ 35,  40,  41],
#          [ 37,  42,  43],
#          [ 38,  43,  44]],
#
#         [[ 85, 100, 109],
#          [ 85,  99, 108],
#          [ 86,  99, 108],
#          ...,
#          [ 35,  40,  41],
#          [ 35,  40,  41],
#          [ 36,  41,  42]],
#
#         ...,
#
#         [[ 76,  84, 113],
#          [ 78,  86, 115],
#          [ 79,  87, 118],
#          ...,
#          [ 67,  74,  93],
#          [ 66,  73,  93],
#          [ 65,  72,  91]],
#
#         [[ 76,  84, 113],
#          [ 78,  86, 116],
#          [ 80,  88, 118],
#          ...,
#          [ 69,  77,  95],
#          [ 68,  76,  95],
#          [ 66,  76,  94]],
#
#         [[ 77,  85, 114],
#          [ 79,  87, 117],
#          [ 81,  89, 119],
#          ...,
#          [ 71,  80, 100],
#          [ 70,  79,  99],
#          [ 69,  78,  98]]], dtype=uint8), array([[[ 94, 106, 116],
#          [ 93, 105, 115],
#          [ 93, 104, 114],
#          ...,
#          [ 34,  37,  42],
#          [ 34,  37,  42],
#          [ 35,  38,  43]],
#
#         [[100, 110, 120],
#          [ 98, 108, 118],
#          [ 96, 106, 116],
#          ...,
#          [ 34,  36,  41],
#          [ 33,  36,  41],
#          [ 33,  36,  41]],
#
#         [[ 96, 106, 116],
#          [ 94, 104, 114],
#          [ 92, 102, 112],
#          ...,
#          [ 33,  35,  41],
#          [ 32,  35,  40],
#          [ 32,  35,  40]],
#
#         ...,
#
#         [[ 77,  91, 121],
#          [ 77,  92, 123],
#          [ 80,  94, 126],
#          ...,
#          [ 51,  54,  68],
#          [ 51,  55,  69],
#          [ 52,  55,  70]],
#
#         [[ 76,  91, 123],
#          [ 78,  93, 125],
#          [ 80,  95, 127],
#          ...,
#          [ 52,  55,  69],
#          [ 52,  55,  71],
#          [ 51,  56,  71]],
#
#         [[ 75,  90, 122],
#          [ 77,  92, 124],
#          [ 80,  95, 127],
#          ...,
#          [ 53,  56,  70],
#          [ 52,  56,  71],
#          [ 51,  56,  71]]], dtype=uint8), array([[[ 81, 110, 107],
#          [ 82, 110, 109],
#          [ 83, 110, 111],
#          ...,
#          [ 36,  43,  48],
#          [ 36,  45,  49],
#          [ 36,  45,  49]],
#
#         [[ 81, 106, 108],
#          [ 84, 109, 111],
#          [ 86, 111, 114],
#          ...,
#          [ 36,  43,  46],
#          [ 36,  44,  47],
#          [ 34,  43,  46]],
#
#         [[ 82, 107, 110],
#          [ 84, 109, 112],
#          [ 87, 111, 115],
#          ...,
#          [ 34,  42,  44],
#          [ 33,  41,  44],
#          [ 32,  40,  44]],
#
#         ...,
#
#         [[ 53,  60,  80],
#          [ 57,  64,  86],
#          [ 61,  70,  93],
#          ...,
#          [ 55,  56,  70],
#          [ 55,  57,  71],
#          [ 55,  58,  73]],
#
#         [[ 53,  60,  80],
#          [ 57,  64,  86],
#          [ 61,  69,  93],
#          ...,
#          [ 58,  59,  73],
#          [ 58,  59,  74],
#          [ 57,  60,  75]],
#
#         [[ 54,  61,  81],
#          [ 57,  65,  87],
#          [ 62,  69,  93],
#          ...,
#          [ 59,  59,  74],
#          [ 59,  61,  75],
#          [ 59,  62,  77]]], dtype=uint8), array([[[ 77,  96, 103],
#          [ 78,  96, 103],
#          [ 80,  97, 105],
#          ...,
#          [ 32,  39,  40],
#          [ 30,  38,  39],
#          [ 28,  37,  40]],
#
#         [[ 73,  92,  98],
#          [ 74,  92,  98],
#          [ 76,  93, 101],
#          ...,
#          [ 31,  37,  40],
#          [ 29,  37,  39],
#          [ 27,  36,  39]],
#
#         [[ 77,  95, 103],
#          [ 80,  97, 104],
#          [ 83,  99, 107],
#          ...,
#          [ 31,  38,  42],
#          [ 29,  37,  40],
#          [ 28,  37,  40]],
#
#         ...,
#
#         [[ 56,  63,  83],
#          [ 59,  67,  89],
#          [ 63,  71,  95],
#          ...,
#          [ 62,  68,  81],
#          [ 62,  67,  81],
#          [ 62,  67,  82]],
#
#         [[ 58,  65,  85],
#          [ 61,  68,  90],
#          [ 64,  72,  96],
#          ...,
#          [ 63,  70,  84],
#          [ 62,  70,  84],
#          [ 62,  69,  84]],
#
#         [[ 60,  67,  87],
#          [ 62,  70,  92],
#          [ 65,  73,  97],
#          ...,
#          [ 65,  72,  87],
#          [ 65,  72,  87],
#          [ 65,  72,  87]]], dtype=uint8), array([[[ 94, 106, 116],
#          [ 94, 105, 115],
#          [ 94, 103, 114],
#          ...,
#          [ 35,  43,  46],
#          [ 34,  44,  46],
#          [ 34,  44,  44]],
#
#         [[ 95, 108, 116],
#          [ 93, 106, 114],
#          [ 92, 104, 113],
#          ...,
#          [ 35,  43,  46],
#          [ 35,  44,  47],
#          [ 35,  44,  46]],
#
#         [[ 92, 105, 113],
#          [ 91, 104, 112],
#          [ 90, 103, 111],
#          ...,
#          [ 36,  45,  48],
#          [ 36,  45,  48],
#          [ 36,  45,  48]],
#
#         ...,
#
#         [[ 71,  81, 105],
#          [ 73,  83, 110],
#          [ 76,  85, 114],
#          ...,
#          [ 65,  68,  82],
#          [ 64,  68,  82],
#          [ 64,  68,  82]],
#
#         [[ 72,  82, 106],
#          [ 73,  84, 110],
#          [ 75,  86, 114],
#          ...,
#          [ 66,  70,  84],
#          [ 65,  70,  84],
#          [ 65,  71,  84]],
#
#         [[ 72,  82, 106],
#          [ 73,  84, 110],
#          [ 75,  86, 114],
#          ...,
#          [ 66,  71,  86],
#          [ 65,  71,  86],
#          [ 65,  72,  87]]], dtype=uint8), array([[[ 92, 105, 113],
#          [ 92, 105, 113],
#          [ 93, 106, 114],
#          ...,
#          [ 38,  48,  51],
#          [ 38,  47,  50],
#          [ 37,  46,  50]],
#
#         [[ 94, 108, 115],
#          [ 94, 108, 116],
#          [ 94, 107, 115],
#          ...,
#          [ 39,  48,  52],
#          [ 39,  48,  52],
#          [ 39,  48,  52]],
#
#         [[ 94, 107, 115],
#          [ 92, 105, 113],
#          [ 91, 104, 112],
#          ...,
#          [ 41,  50,  54],
#          [ 40,  49,  53],
#          [ 40,  49,  53]],
#
#         ...,
#
#         [[ 37,  42,  57],
#          [ 42,  49,  66],
#          [ 49,  56,  76],
#          ...,
#          [ 71,  81,  98],
#          [ 72,  82,  99],
#          [ 73,  83, 100]],
#
#         [[ 38,  43,  58],
#          [ 44,  50,  67],
#          [ 51,  58,  77],
#          ...,
#          [ 73,  84, 101],
#          [ 74,  85, 102],
#          [ 75,  85, 102]],
#
#         [[ 40,  45,  60],
#          [ 46,  52,  70],
#          [ 54,  61,  80],
#          ...,
#          [ 74,  85, 103],
#          [ 74,  86, 104],
#          [ 75,  87, 105]]], dtype=uint8), array([[[ 90, 102, 112],
#          [ 89, 101, 112],
#          [ 89, 101, 113],
#          ...,
#          [ 33,  44,  48],
#          [ 31,  42,  46],
#          [ 30,  41,  45]],
#
#         [[ 90, 102, 112],
#          [ 89, 101, 112],
#          [ 88, 100, 112],
#          ...,
#          [ 34,  44,  48],
#          [ 32,  43,  48],
#          [ 31,  43,  47]],
#
#         [[ 90, 102, 112],
#          [ 90, 102, 112],
#          [ 89, 101, 112],
#          ...,
#          [ 35,  46,  50],
#          [ 34,  45,  49],
#          [ 33,  45,  49]],
#
#         ...,
#
#         [[ 55,  62,  82],
#          [ 60,  67,  89],
#          [ 67,  74,  97],
#          ...,
#          [ 66,  73,  88],
#          [ 67,  75,  89],
#          [ 67,  77,  91]],
#
#         [[ 55,  62,  82],
#          [ 61,  68,  90],
#          [ 68,  75,  99],
#          ...,
#          [ 66,  75,  89],
#          [ 66,  75,  90],
#          [ 67,  76,  91]],
#
#         [[ 56,  63,  83],
#          [ 61,  68,  91],
#          [ 67,  75, 100],
#          ...,
#          [ 66,  77,  90],
#          [ 67,  77,  92],
#          [ 69,  77,  94]]], dtype=uint8), array([[[ 88, 100, 112],
#          [ 89,  99, 112],
#          [ 90,  99, 112],
#          ...,
#          [ 30,  42,  46],
#          [ 30,  41,  45],
#          [ 29,  41,  45]],
#
#         [[ 89, 101, 113],
#          [ 90, 101, 113],
#          [ 92, 101, 113],
#          ...,
#          [ 28,  40,  44],
#          [ 28,  40,  44],
#          [ 27,  39,  43]],
#
#         [[ 89, 101, 111],
#          [ 91, 101, 112],
#          [ 91, 101, 112],
#          ...,
#          [ 30,  42,  46],
#          [ 29,  41,  45],
#          [ 28,  40,  43]],
#
# ...
#          [106, 120, 132],
#          [105, 119, 131],
#          ...,
#          [ 34,  38,  49],
#          [ 35,  39,  50],
#          [ 37,  41,  52]],
#
#         [[108, 122, 134],
#          [107, 121, 133],
#          [105, 119, 131],
#          ...,
#          [ 34,  37,  49],
#          [ 35,  39,  50],
#          [ 36,  40,  51]],
#
#         [[107, 123, 135],
#          [105, 121, 134],
#          [103, 118, 131],
#          ...,
#          [ 34,  36,  50],
#          [ 34,  37,  50],
#          [ 35,  39,  50]],
#
#         ...,
#
#         [[ 14,  13,  16],
#          [ 14,  13,  16],
#          [ 14,  13,  17],
#          ...,
#          [ 94, 108, 134],
#          [ 93, 108, 134],
#          [ 92, 106, 133]],
#
#         [[ 14,  13,  15],
#          [ 14,  13,  15],
#          [ 14,  13,  16],
#          ...,
#          [ 95, 108, 134],
#          [ 95, 108, 134],
#          [ 93, 106, 132]],
#
#         [[ 14,  13,  15],
#          [ 14,  13,  16],
#          [ 15,  14,  16],
#          ...,
#          [ 95, 108, 134],
#          [ 95, 108, 134],
#          [ 94, 107, 133]]], dtype=uint8), array([[[105, 118, 132],
#          [106, 120, 132],
#          [108, 122, 134],
#          ...,
#          [ 49,  53,  64],
#          [ 53,  57,  68],
#          [ 58,  62,  73]],
#
#         [[108, 121, 134],
#          [107, 121, 134],
#          [107, 121, 133],
#          ...,
#          [ 48,  52,  63],
#          [ 52,  56,  67],
#          [ 57,  61,  72]],
#
#         [[109, 122, 136],
#          [108, 122, 134],
#          [107, 121, 133],
#          ...,
#          [ 48,  52,  63],
#          [ 51,  55,  66],
#          [ 54,  58,  69]],
#
#         ...,
#
#         [[ 17,  13,  18],
#          [ 17,  13,  18],
#          [ 16,  13,  18],
#          ...,
#          [ 86, 105, 130],
#          [ 86, 106, 130],
#          [ 87, 108, 130]],
#
#         [[ 17,  14,  16],
#          [ 16,  14,  16],
#          [ 14,  14,  16],
#          ...,
#          [ 87, 107, 129],
#          [ 86, 107, 129],
#          [ 86, 107, 129]],
#
#         [[ 18,  15,  17],
#          [ 16,  14,  16],
#          [ 15,  14,  16],
#          ...,
#          [ 90, 108, 131],
#          [ 89, 108, 131],
#          [ 87, 108, 130]]], dtype=uint8), array([[[110, 123, 137],
#          [109, 122, 136],
#          [109, 122, 136],
#          ...,
#          [ 35,  41,  51],
#          [ 35,  42,  51],
#          [ 36,  43,  52]],
#
#         [[111, 124, 138],
#          [110, 123, 137],
#          [109, 123, 136],
#          ...,
#          [ 36,  41,  51],
#          [ 36,  41,  52],
#          [ 36,  42,  53]],
#
#         [[110, 123, 137],
#          [108, 122, 136],
#          [106, 120, 134],
#          ...,
#          [ 36,  40,  51],
#          [ 37,  41,  52],
#          [ 37,  42,  53]],
#
#         ...,
#
#         [[ 19,  18,  20],
#          [ 17,  16,  18],
#          [ 15,  14,  16],
#          ...,
#          [ 91, 105, 133],
#          [ 91, 105, 132],
#          [ 90, 105, 131]],
#
#         [[ 19,  18,  20],
#          [ 17,  16,  18],
#          [ 16,  15,  17],
#          ...,
#          [ 92, 105, 132],
#          [ 91, 105, 131],
#          [ 90, 105, 131]],
#
#         [[ 21,  20,  22],
#          [ 19,  18,  19],
#          [ 17,  16,  18],
#          ...,
#          [ 92, 105, 131],
#          [ 90, 104, 130],
#          [ 90, 105, 131]]], dtype=uint8), array([[[ 72,  93, 101],
#          [ 75,  95, 103],
#          [ 79,  98, 106],
#          ...,
#          [ 35,  39,  50],
#          [ 36,  40,  51],
#          [ 37,  41,  52]],
#
#         [[ 72,  94, 102],
#          [ 75,  96, 104],
#          [ 80, 100, 108],
#          ...,
#          [ 36,  39,  50],
#          [ 37,  40,  52],
#          [ 38,  42,  53]],
#
#         [[ 73,  96, 104],
#          [ 77,  99, 106],
#          [ 82, 103, 111],
#          ...,
#          [ 35,  38,  50],
#          [ 36,  40,  51],
#          [ 37,  41,  52]],
#
#         ...,
#
#         [[ 11,  13,  14],
#          [ 12,  14,  15],
#          [ 12,  14,  15],
#          ...,
#          [ 89, 103, 130],
#          [ 88, 103, 129],
#          [ 88, 103, 129]],
#
#         [[ 12,  14,  15],
#          [ 12,  14,  15],
#          [ 12,  14,  15],
#          ...,
#          [ 90, 103, 129],
#          [ 89, 103, 129],
#          [ 88, 103, 129]],
#
#         [[ 13,  15,  15],
#          [ 13,  15,  15],
#          [ 13,  15,  15],
#          ...,
#          [ 90, 103, 129],
#          [ 89, 103, 129],
#          [ 89, 104, 130]]], dtype=uint8), array([[[ 88, 113, 123],
#          [ 86, 111, 121],
#          [ 83, 108, 118],
#          ...,
#          [ 33,  34,  45],
#          [ 33,  35,  46],
#          [ 33,  35,  46]],
#
#         [[ 82, 109, 117],
#          [ 79, 107, 114],
#          [ 77, 104, 111],
#          ...,
#          [ 32,  34,  45],
#          [ 32,  34,  45],
#          [ 32,  34,  45]],
#
#         [[ 76, 104, 112],
#          [ 74, 102, 110],
#          [ 73, 100, 107],
#          ...,
#          [ 32,  34,  45],
#          [ 32,  34,  45],
#          [ 32,  34,  45]],
#
#         ...,
#
#         [[ 19,  18,  22],
#          [ 18,  16,  19],
#          [ 17,  15,  17],
#          ...,
#          [ 88, 100, 128],
#          [ 91, 103, 131],
#          [ 92, 104, 132]],
#
#         [[ 18,  17,  21],
#          [ 18,  16,  19],
#          [ 18,  15,  17],
#          ...,
#          [ 89, 100, 128],
#          [ 93, 104, 132],
#          [ 96, 107, 135]],
#
#         [[ 19,  18,  22],
#          [ 19,  17,  20],
#          [ 18,  16,  18],
#          ...,
#          [ 91, 102, 130],
#          [ 94, 105, 133],
#          [ 96, 107, 135]]], dtype=uint8), array([[[101, 118, 127],
#          [ 98, 115, 124],
#          [ 93, 110, 119],
#          ...,
#          [ 29,  33,  38],
#          [ 29,  33,  38],
#          [ 30,  34,  39]],
#
#         [[ 99, 116, 125],
#          [ 95, 112, 121],
#          [ 89, 106, 115],
#          ...,
#          [ 31,  35,  40],
#          [ 31,  35,  40],
#          [ 30,  35,  40]],
#
#         [[ 96, 113, 122],
#          [ 91, 108, 117],
#          [ 85, 102, 111],
#          ...,
#          [ 31,  36,  41],
#          [ 30,  36,  41],
#          [ 30,  36,  41]],
#
#         ...,
#
#         [[ 19,  19,  25],
#          [ 19,  19,  24],
#          [ 18,  18,  24],
#          ...,
#          [ 97, 108, 136],
#          [100, 111, 139],
#          [101, 112, 140]],
#
#         [[ 20,  20,  26],
#          [ 20,  20,  25],
#          [ 19,  19,  23],
#          ...,
#          [102, 113, 140],
#          [102, 114, 142],
#          [103, 114, 142]],
#
#         [[ 23,  22,  26],
#          [ 22,  21,  24],
#          [ 21,  20,  23],
#          ...,
#          [104, 117, 143],
#          [103, 116, 142],
#          [103, 116, 142]]], dtype=uint8), array([[[106, 125, 133],
#          [104, 123, 131],
#          [101, 120, 128],
#          ...,
#          [ 35,  38,  49],
#          [ 35,  39,  50],
#          [ 36,  40,  51]],
#
#         [[105, 123, 130],
#          [104, 121, 129],
#          [101, 118, 127],
#          ...,
#          [ 33,  38,  47],
#          [ 34,  39,  49],
#          [ 35,  40,  49]],
#
#         [[103, 121, 128],
#          [101, 118, 127],
#          [ 98, 115, 125],
#          ...,
#          [ 33,  38,  47],
#          [ 34,  39,  48],
#          [ 35,  40,  49]],
#
#         ...,
#
#         [[ 23,  23,  27],
#          [ 23,  22,  26],
#          [ 22,  21,  25],
#          ...,
#          [ 84, 100, 127],
#          [ 84, 101, 127],
#          [ 84, 101, 127]],
#
#         [[ 21,  22,  26],
#          [ 22,  22,  26],
#          [ 23,  22,  26],
#          ...,
#          [ 84, 101, 127],
#          [ 84, 102, 127],
#          [ 85, 102, 128]],
#
#         [[ 22,  23,  27],
#          [ 23,  23,  27],
#          [ 23,  22,  26],
#          ...,
#          [ 86, 102, 129],
#          [ 85, 103, 129],
#          [ 84, 104, 129]]], dtype=uint8), array([[[ 81, 100, 108],
#          [ 85, 104, 112],
#          [ 91, 110, 117],
#          ...,
#          [ 35,  37,  51],
#          [ 36,  38,  51],
#          [ 36,  40,  51]],
#
#         [[ 80, 101, 109],
#          [ 87, 106, 114],
#          [ 94, 113, 121],
#          ...,
#          [ 34,  35,  49],
#          [ 34,  36,  49],
#          [ 34,  38,  49]],
#
#         [[ 81, 102, 110],
#          [ 88, 108, 115],
#          [ 95, 114, 122],
#          ...,
#          [ 32,  33,  47],
#          [ 32,  34,  47],
#          [ 32,  35,  46]],
#
#         ...,
#
#         [[ 22,  25,  30],
#          [ 21,  24,  29],
#          [ 21,  24,  29],
#          ...,
#          [ 87,  98, 128],
#          [ 87,  98, 128],
#          [ 87,  98, 128]],
#
#         [[ 21,  24,  29],
#          [ 21,  24,  29],
#          [ 21,  24,  29],
#          ...,
#          [ 87,  98, 128],
#          [ 86,  98, 128],
#          [ 85,  99, 127]],
#
#         [[ 20,  24,  29],
#          [ 20,  24,  29],
#          [ 21,  24,  29],
#          ...,
#          [ 85,  99, 128],
#          [ 85,  99, 127],
#          [ 85,  99, 127]]], dtype=uint8), array([[[112, 121, 135],
#          [109, 118, 132],
#          [105, 114, 128],
#          ...,
#          [ 48,  52,  62],
#          [ 50,  55,  64],
#          [ 52,  57,  66]],
#
#         [[107, 118, 132],
#          [103, 114, 128],
#          [ 99, 109, 123],
#          ...,
#          [ 46,  50,  59],
#          [ 47,  52,  61],
#          [ 49,  54,  63]],
#
#         [[103, 114, 128],
#          [ 99, 110, 124],
#          [ 95, 106, 120],
#          ...,
#          [ 44,  48,  58],
#          [ 45,  50,  59],
#          [ 46,  51,  60]],
#
#         ...,
#
#         [[ 23,  28,  37],
#          [ 23,  28,  37],
#          [ 22,  27,  36],
#          ...,
#          [ 85, 104, 130],
#          [ 86, 106, 131],
#          [ 88, 108, 133]],
#
#         [[ 22,  27,  36],
#          [ 21,  26,  35],
#          [ 20,  26,  35],
#          ...,
#          [ 86, 104, 130],
#          [ 86, 106, 131],
#          [ 88, 108, 133]],
#
#         [[ 23,  28,  37],
#          [ 22,  27,  36],
#          [ 20,  26,  35],
#          ...,
#          [ 85, 104, 130],
#          [ 86, 106, 131],
#          [ 88, 108, 133]]], dtype=uint8), array([[[ 87, 103, 115],
#          [ 86, 103, 114],
#          [ 85, 103, 114],
#          ...,
#          [ 46,  52,  61],
#          [ 47,  54,  63],
#          [ 49,  56,  65]],
#
#         [[ 85, 101, 113],
#          [ 84, 101, 113],
#          [ 85, 103, 114],
#          ...,
#          [ 42,  48,  58],
#          [ 42,  49,  58],
#          [ 43,  50,  59]],
#
#         [[ 84, 100, 112],
#          [ 83, 101, 112],
#          [ 85, 103, 114],
#          ...,
#          [ 41,  47,  56],
#          [ 40,  47,  56],
#          [ 40,  47,  56]],
#
#         ...,
#
#         [[ 20,  27,  36],
#          [ 22,  28,  36],
#          [ 23,  29,  35],
#          ...,
#          [ 92, 115, 138],
#          [ 93, 117, 139],
#          [ 94, 118, 140]],
#
#         [[ 20,  27,  36],
#          [ 21,  28,  35],
#          [ 22,  28,  35],
#          ...,
#          [ 93, 115, 139],
#          [ 94, 118, 140],
#          [ 95, 119, 141]],
#
#         [[ 19,  26,  35],
#          [ 21,  27,  35],
#          [ 22,  28,  35],
#          ...,
#          [ 93, 115, 140],
#          [ 95, 117, 142],
#          [ 96, 120, 144]]], dtype=uint8), array([[[ 89, 109, 120],
#          [ 88, 108, 119],
#          [ 86, 106, 117],
#          ...,
#          [ 32,  35,  43],
#          [ 32,  35,  44],
#          [ 33,  35,  45]],
#
#         [[ 90, 110, 121],
#          [ 88, 108, 119],
#          [ 86, 106, 117],
#          ...,
#          [ 33,  36,  44],
#          [ 32,  36,  44],
#          [ 31,  36,  45]],
#
#         [[ 91, 110, 121],
#          [ 89, 108, 118],
#          [ 86, 106, 114],
#          ...,
#          [ 32,  35,  43],
#          [ 32,  36,  44],
#          [ 31,  37,  44]],
#
#         ...,
#
#         [[ 28,  29,  33],
#          [ 27,  28,  32],
#          [ 27,  28,  31],
#          ...,
#          [ 93, 112, 139],
#          [ 91, 111, 137],
#          [ 90, 110, 135]],
#
#         [[ 28,  29,  33],
#          [ 27,  28,  32],
#          [ 27,  28,  31],
#          ...,
#          [ 94, 114, 140],
#          [ 92, 112, 138],
#          [ 90, 110, 135]],
#
#         [[ 29,  30,  34],
#          [ 28,  29,  33],
#          [ 27,  28,  32],
#          ...,
#          [ 96, 115, 142],
#          [ 93, 112, 139],
#          [ 91, 110, 137]]], dtype=uint8), array([[[ 89, 107, 118],
#          [ 88, 106, 117],
#          [ 85, 104, 115],
#          ...,
#          [ 36,  41,  50],
#          [ 37,  42,  51],
#          [ 38,  43,  52]],
#
#         [[ 87, 105, 116],
#          [ 86, 105, 115],
#          [ 85, 103, 114],
#          ...,
#          [ 36,  40,  49],
#          [ 37,  41,  50],
#          [ 37,  42,  51]],
#
#         [[ 84, 103, 114],
#          [ 83, 102, 113],
#          [ 82, 103, 113],
#          ...,
#          [ 34,  39,  48],
#          [ 35,  41,  49],
#          [ 34,  41,  50]],
#
#         ...,
#
#         [[ 28,  31,  35],
#          [ 28,  31,  35],
#          [ 28,  31,  35],
#          ...,
#          [ 91, 112, 139],
#          [ 90, 112, 138],
#          [ 88, 112, 136]],
#
#         [[ 28,  31,  36],
#          [ 28,  31,  35],
#          [ 29,  31,  35],
#          ...,
#          [ 91, 113, 138],
#          [ 90, 113, 137],
#          [ 88, 112, 136]],
#
#         [[ 29,  32,  37],
#          [ 29,  32,  37],
#          [ 29,  32,  36],
#          ...,
#          [ 91, 113, 138],
#          [ 90, 113, 137],
#          [ 88, 112, 136]]], dtype=uint8), array([[[ 83, 103, 114],
#          [ 82, 104, 115],
#          [ 82, 104, 115],
#          ...,
#          [ 29,  37,  44],
#          [ 29,  37,  44],
#          [ 30,  38,  45]],
#
#         [[ 84, 104, 115],
#          [ 84, 104, 115],
#          [ 84, 105, 116],
#          ...,
#          [ 29,  37,  44],
#          [ 29,  37,  44],
#          [ 30,  38,  45]],
#
#         [[ 86, 105, 116],
#          [ 87, 105, 116],
#          [ 86, 106, 117],
#          ...,
#          [ 30,  37,  42],
#          [ 30,  37,  42],
#          [ 30,  36,  42]],
#
#         ...,
#
#         [[ 30,  30,  36],
#          [ 29,  29,  35],
#          [ 28,  28,  34],
#          ...,
#          [ 96, 117, 144],
#          [ 95, 117, 143],
#          [ 95, 116, 143]],
#
#         [[ 30,  30,  36],
#          [ 29,  29,  35],
#          [ 28,  28,  34],
#          ...,
#          [ 97, 117, 144],
#          [ 95, 116, 143],
#          [ 95, 116, 143]],
#
#         [[ 30,  30,  36],
#          [ 29,  29,  35],
#          [ 27,  27,  33],
#          ...,
#          [ 97, 117, 144],
#          [ 95, 116, 143],
#          [ 95, 116, 143]]], dtype=uint8), array([[[ 83, 105, 116],
#          [ 83, 105, 117],
#          [ 84, 106, 117],
#          ...,
#          [ 32,  40,  48],
#          [ 35,  41,  50],
#          [ 38,  43,  52]],
#
#         [[ 84, 106, 117],
#          [ 84, 106, 117],
#          [ 84, 106, 117],
#          ...,
#          [ 31,  39,  47],
#          [ 34,  40,  49],
#          [ 37,  42,  51]],
#
#         [[ 87, 107, 118],
#          [ 86, 107, 118],
#          [ 85, 106, 117],
#          ...,
#          [ 32,  38,  46],
#          [ 35,  40,  49],
#          [ 38,  41,  51]],
#
#         ...,
#
#         [[ 24,  24,  30],
#          [ 24,  24,  30],
#          [ 24,  24,  30],
#          ...,
#          [ 95, 117, 142],
#          [ 95, 118, 143],
#          [ 96, 118, 143]],
#
#         [[ 25,  25,  31],
#          [ 25,  25,  30],
#          [ 25,  24,  30],
#          ...,
#          [ 96, 118, 143],
#          [ 96, 118, 143],
#          [ 96, 118, 143]],
#
#         [[ 25,  25,  31],
#          [ 25,  25,  31],
#          [ 25,  25,  31],
#          ...,
#          [ 96, 118, 143],
#          [ 96, 118, 143],
#          [ 96, 118, 143]]], dtype=uint8), array([[[ 87, 105, 116],
#          [ 87, 106, 115],
#          [ 87, 107, 115],
#          ...,
#          [ 32,  38,  45],
#          [ 33,  38,  45],
#          [ 35,  38,  46]],
#
#         [[ 88, 106, 117],
#          [ 88, 107, 116],
#          [ 88, 107, 115],
#          ...,
#          [ 30,  36,  43],
#          [ 32,  37,  44],
#          [ 34,  37,  45]],
#
#         [[ 88, 107, 116],
#          [ 89, 108, 116],
#          [ 89, 108, 116],
#          ...,
#          [ 30,  36,  43],
#          [ 32,  36,  44],
#          [ 34,  37,  45]],
#
#         ...,
#
#         [[ 24,  24,  30],
#          [ 23,  24,  29],
#          [ 23,  23,  28],
#          ...,
#          [ 97, 119, 144],
#          [ 96, 118, 143],
#          [ 96, 118, 143]],
#
#         [[ 24,  24,  30],
#          [ 24,  24,  30],
#          [ 23,  23,  29],
#          ...,
#          [ 97, 119, 144],
#          [ 96, 118, 143],
#          [ 96, 118, 143]],
#
#         [[ 25,  25,  31],
#          [ 24,  24,  30],
#          [ 24,  24,  29],
#          ...,
#          [ 96, 118, 143],
#          [ 96, 118, 143],
#          [ 96, 118, 143]]], dtype=uint8)]
